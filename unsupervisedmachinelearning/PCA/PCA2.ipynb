# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x = df[['Annual Income (k$)','Spending Score (1-100)','Age']]
x
# Out:
#      Annual Income (k$)  Spending Score (1-100)  Age
# 0                    15                      39   19
# 1                    15                      81   21
# 2                    16                       6   20
# 3                    16                      77   23
# 4                    17                      40   31
# ..                  ...                     ...  ...
# 195                 120                      79   35
# 196                 126                      28   45
# 197                 126                      74   32
# 198                 137                      18   32
# 199                 137                      83   30
#
# [200 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
scaled_x = sc.fit_transform(x)

# %%
scaled_x
# Out:
# array([[-1.73899919, -0.43480148, -1.42456879],
#        [-1.73899919,  1.19570407, -1.28103541],
#        [-1.70082976, -1.71591298, -1.3528021 ],
#        [-1.70082976,  1.04041783, -1.13750203],
#        [-1.66266033, -0.39597992, -0.56336851],
#        [-1.66266033,  1.00159627, -1.20926872],
#        [-1.62449091, -1.71591298, -0.27630176],
#        [-1.62449091,  1.70038436, -1.13750203],
#        [-1.58632148, -1.83237767,  1.80493225],
#        [-1.58632148,  0.84631002, -0.6351352 ],
#        [-1.58632148, -1.4053405 ,  2.02023231],
#        [-1.58632148,  1.89449216, -0.27630176],
#        [-1.54815205, -1.36651894,  1.37433211],
#        [-1.54815205,  1.04041783, -1.06573534],
#        [-1.54815205, -1.44416206, -0.13276838],
#        [-1.54815205,  1.11806095, -1.20926872],
#        [-1.50998262, -0.59008772, -0.27630176],
#        [-1.50998262,  0.61338066, -1.3528021 ],
#        [-1.43364376, -0.82301709,  0.94373197],
#        [-1.43364376,  1.8556706 , -0.27630176],
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca_features = pca.fit_transform(scaled_x)

# %%
pca_features
# Out:
# array([[-6.15720019e-01, -1.76348088e+00],
#        [-1.66579271e+00, -1.82074695e+00],
#        [ 3.37861909e-01, -1.67479894e+00],
#        [-1.45657325e+00, -1.77242992e+00],
#        [-3.84652078e-02, -1.66274012e+00],
#        [-1.48168526e+00, -1.73500173e+00],
#        [ 1.09461665e+00, -1.56610230e+00],
#        [-1.92630736e+00, -1.72111049e+00],
#        [ 2.64517786e+00, -1.46084721e+00],
#        [-9.70130513e-01, -1.63558108e+00],
#        [ 2.49568861e+00, -1.47048914e+00],
#        [-1.45688256e+00, -1.66436050e+00],
#        [ 2.01018729e+00, -1.45329897e+00],
#        [-1.41321072e+00, -1.61776746e+00],
#        [ 1.00042965e+00, -1.49579176e+00],
#        [-1.56943170e+00, -1.62502669e+00],
#        [ 2.94060318e-01, -1.49425585e+00],
#        [-1.31624924e+00, -1.57216383e+00],
#        [ 1.31669910e+00, -1.37243404e+00],
#        [-1.43679899e+00, -1.51039469e+00],
#        [ 2.88561175e-01, -1.37988135e+00],
#        [-1.26018513e+00, -1.45723906e+00],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x['Annual Income (k$)'],x['Spending Score (1-100)'],c=encoded_labels)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('ORiginal Data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.scatter(x['Annual Income (k$)'],x['Spending Score (1-100)'],c=encoded_labels)
#       2 plt.xlabel('Sepal Length')
#       3 plt.ylabel('Sepal Width')
#
# NameError: name 'encoded_labels' is not defined

# %%
plt.scatter(pca_features[:,0],pca_features[:,1],c=encoded_labels)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Data After PCA')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plt.scatter(pca_features[:,0],pca_features[:,1],c=encoded_labels)
#       2 plt.xlabel('PC1')
#       3 plt.ylabel('PC2')
#
# NameError: name 'encoded_labels' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:4439, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4438 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4439     colors = mcolors.to_rgba_array(c)
#    4440 except (TypeError, ValueError) as err:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:487, in to_rgba_array(c, alpha)
#     486 else:
# --> 487     rgba = np.array([to_rgba(cc) for cc in c])
#     489 if alpha is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:487, in <listcomp>(.0)
#     486 else:
# --> 487     rgba = np.array([to_rgba(cc) for cc in c])
#     489 if alpha is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:299, in to_rgba(c, alpha)
# ...
