# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
with open('pracitsedata.csv', 'r', encoding='utf-8', errors='ignore') as file:
    df=pd.read_csv(file)
df
# Out:
#       Year          State  State.Minimum.Wage  \
# 0     1968        Alabama             0.00000
# 1     1968         Alaska             2.10000
# 2     1968        Arizona             0.46800
# 3     1968       Arkansas             0.15625
# 4     1968     California             1.65000
# ...    ...            ...                 ...
# 2857  2020       Virginia             7.25000
# 2858  2020     Washington            13.50000
# 2859  2020  West Virginia             8.75000
# 2860  2020      Wisconsin             7.25000
# 2861  2020        Wyoming             5.15000
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.00                  1.15
# 1                               15.61                  1.15
# 2                                3.48                  1.15
# 3                                1.16                  1.15
# 4                               12.26                  1.15
# ...

# %%
df.dtypes
# Out:
# Year                                                     int64
# State                                                   object
# State.Minimum.Wage                                     float64
# State.Minimum.Wage.2020.Dollars                        float64
# Federal.Minimum.Wage                                   float64
# Federal.Minimum.Wage.2020.Dollars                      float64
# Effective.Minimum.Wage                                 float64
# Effective.Minimum.Wage.2020.Dollars                    float64
# CPI.Average                                            float64
# Department.Of.Labor.Uncleaned.Data                      object
# Department.Of.Labor.Cleaned.Low.Value                  float64
# Department.Of.Labor.Cleaned.Low.Value.2020.Dollars     float64
# Department.Of.Labor.Cleaned.High.Value                 float64
# Department.Of.Labor.Cleaned.High.Value.2020.Dollars    float64
# Footnote                                                object
# dtype: object

# %%
df.head()
# Out:
#    Year       State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0  1968     Alabama             0.00000                             0.00
# 1  1968      Alaska             2.10000                            15.61
# 2  1968     Arizona             0.46800                             3.48
# 3  1968    Arkansas             0.15625                             1.16
# 4  1968  California             1.65000                            12.26
#
#    Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                  1.15                               8.55
# 1                  1.15                               8.55
# 2                  1.15                               8.55
# 3                  1.15                               8.55
# 4                  1.15                               8.55
#
#    Effective.Minimum.Wage  Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                    1.15                                 8.55         34.8
# ...

# %%
df['Department.Of.Labor.Cleaned.High.Value.2020.Dollars'].unique()
# Out:
# array([ 0.  , 15.61,  4.91,  1.16, 12.26,  9.29, 10.41,  8.55,  5.57,
#        11.89,  7.43,  3.72,   nan,  8.92, 14.8 ,  4.65,  1.1 , 11.63,
#         8.81,  9.87,  8.11,  5.29, 11.28,  7.05,  3.52,  8.46, 14.  ,
#         4.4 ,  7.33, 11.  ,  8.33, 10.67, 13.33,  5.  ,  8.67,  7.67,
#         6.67, 10.  ,  9.67, 13.41,  4.22,  7.03, 10.54,  7.98, 10.22,
#        12.77,  4.79,  8.3 ,  7.34,  6.39,  9.58,  9.26, 12.99,  4.08,
#        10.21,  7.74, 11.45,  9.9 , 13.92, 11.76,  8.66,  4.64, 11.14,
#        10.83,  6.19,  9.28,  8.97,  8.35, 12.23,  3.84,  6.99,  9.61,
#         7.28, 10.78,  9.32, 13.11, 11.07,  8.16,  4.37, 10.49, 10.19,
#         5.83,  8.74,  8.45,  7.86, 11.02,  3.46,  6.3 ,  6.56,  9.71,
#         8.39, 11.8 ,  9.97,  7.35,  3.93,  9.44,  9.18,  5.25,  7.87,
#         7.61,  7.08, 10.1 ,  3.17,  5.77,  7.93,  6.01,  8.89,  7.69,
#        10.82,  9.13,  6.73,  3.61,  8.65,  8.41,  4.81,  7.21,  6.97,
# ...

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Department.Of.Labor.Cleaned.Low.Value.2020.Dollars'].unique()
# Out:
# array([ 0.  , 15.61,  3.48,  1.16, 12.26,  7.43, 10.41,  9.29,  8.55,
#         4.83, 11.89,  5.2 ,  5.57,  3.2 ,  3.16,   nan,  8.92, 14.8 ,
#         3.3 ,  1.1 , 11.63,  7.05,  9.87,  8.81,  8.11,  4.58, 11.28,
#         4.93,  5.29,  3.03,  3.  ,  8.46, 14.  ,  3.12,  7.33, 11.  ,
#         6.67, 10.67,  8.33,  4.33,  8.67,  4.67,  9.67, 10.  ,  5.  ,
#         2.87, 13.41,  2.99,  7.03, 10.54,  6.39, 10.22,  7.98,  4.15,
#         8.3 ,  4.47,  9.26,  9.58,  4.79,  2.75, 12.99,  2.9 , 10.21,
#         6.19, 11.45,  9.9 ,  7.74, 11.76,  8.66,  4.02, 10.83,  4.64,
#         9.28,  8.04,  8.97, 12.23,  2.73,  6.99,  9.61,  5.83, 10.78,
#         9.32,  7.28, 11.07,  8.16,  3.79, 10.19,  4.37,  8.74,  7.57,
#         8.45, 11.02,  2.46,  6.3 ,  5.25,  9.71,  8.39,  6.56,  9.97,
#         7.35,  3.41,  9.18,  3.93,  7.87,  6.82,  7.61, 10.1 ,  2.25,
#         5.77,  7.93,  4.81,  8.89,  7.69,  6.01,  9.13,  6.73,  3.13,
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Year                                                    0.000000
# State                                                   0.000000
# State.Minimum.Wage                                      0.000000
# State.Minimum.Wage.2020.Dollars                         0.000000
# Federal.Minimum.Wage                                    0.000000
# Federal.Minimum.Wage.2020.Dollars                       0.000000
# Effective.Minimum.Wage                                  0.000000
# Effective.Minimum.Wage.2020.Dollars                     0.000000
# CPI.Average                                             0.000000
# Department.Of.Labor.Uncleaned.Data                      0.000000
# Department.Of.Labor.Cleaned.Low.Value                   0.000000
# Department.Of.Labor.Cleaned.Low.Value.2020.Dollars      0.000000
# Department.Of.Labor.Cleaned.High.Value                  0.000000
# Department.Of.Labor.Cleaned.High.Value.2020.Dollars     0.000000
# ...

# %%
w=df['Department.Of.Labor.Cleaned.Low.Value.2020.Dollars'].mean()

# %%
df['Department.Of.Labor.Cleaned.Low.Value.2020.Dollars'].replace(np.nan,w,inplace=True)

# %%
w1=df['Department.Of.Labor.Cleaned.High.Value.2020.Dollars'].mean()

# %%
df['Department.Of.Labor.Cleaned.High.Value.2020.Dollars'].replace(np.nan,w1,inplace=True)

# %%
df['Footnote'].unique()
# Out:
# array([nan, '(b)', '(f)', '(g)', '(i)', '(g, j)', '[c]', '(h)', '(d)',
#        '(e)', '(j)', '(i2)'], dtype=object)

# %%
df['Footnote'].value_counts()
# Out:
# (g)       105
# [c]        99
# (b)        80
# (e)        74
# (d)        36
# (i)        26
# (g, j)     15
# (j)        13
# (i2)        4
# (f)         3
# (h)         1
# Name: Footnote, dtype: int64

# %%
df['Footnote'].fillna('(g)',inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,10))
sb.boxplot(data=df,x='State.Minimum.Wage',y='State')
# Out:
# <Axes: xlabel='State.Minimum.Wage', ylabel='State'>

# %%
df[(df['State']=='Montana')&(df['State.Minimum.Wage']>7)]
# Out:
#       Year    State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 2511  2014  Montana                7.90                             8.63
# 2565  2015  Montana                8.05                             8.79
# 2619  2016  Montana                8.05                             8.68
# 2673  2017  Montana                8.15                             8.60
# 2727  2018  Montana                8.30                             8.55
# 2781  2019  Montana                8.65                             8.75
# 2835  2020  Montana                8.65                             8.65
#
#       Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 2511                  7.25                               7.92
# 2565                  7.25                               7.91
# 2619                  7.25                               7.81
# 2673                  7.25                               7.65
# 2727                  7.25                               7.47
# ...

# %%
w2=df[(df['State']=='Montana')&(df['State.Minimum.Wage']>7)].index
w2
# Out:
# Int64Index([2511, 2565, 2619, 2673, 2727, 2781, 2835], dtype='int64')

# %%
df.drop(w2,inplace=True)

# %%
plt.figure(figsize=(20,10))
sb.boxplot(data=df,x='State.Minimum.Wage',y='State')
# Out:
# <Axes: xlabel='State.Minimum.Wage', ylabel='State'>

# %%
w3=df[(df['State']=='Kansas')&(df['State.Minimum.Wage']>0)]
w3
# Out:
#       Year   State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 611   1979  Kansas                1.60                             5.70
# 665   1980  Kansas                1.60                             5.02
# 719   1981  Kansas                1.60                             4.55
# 773   1982  Kansas                1.60                             4.29
# 827   1983  Kansas                1.60                             4.16
# 881   1984  Kansas                1.60                             3.98
# 935   1985  Kansas                1.60                             3.85
# 989   1986  Kansas                1.60                             3.78
# 1043  1987  Kansas                1.60                             3.64
# 1097  1988  Kansas                1.60                             3.50
# 1151  1989  Kansas                1.60                             3.34
# 1205  1990  Kansas                1.60                             3.17
# ...

# %%
df.drop(w3,inplace=True)

# %%
w4=df[(df['State']=='U.S. Virgin Islands')&(df['State.Minimum.Wage']<1)].index
w4
# Out:
# Int64Index([46, 100, 154, 208, 262, 316, 370, 424, 478, 532, 586], dtype='int64')

# %%
df.drop(w4,inplace=True)

# %%
df
# Out:
#       Year          State  State.Minimum.Wage  \
# 0     1968        Alabama             0.00000
# 1     1968         Alaska             2.10000
# 2     1968        Arizona             0.46800
# 3     1968       Arkansas             0.15625
# 4     1968     California             1.65000
# ...    ...            ...                 ...
# 2857  2020       Virginia             7.25000
# 2858  2020     Washington            13.50000
# 2859  2020  West Virginia             8.75000
# 2860  2020      Wisconsin             7.25000
# 2861  2020        Wyoming             5.15000
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.00                  1.15
# 1                               15.61                  1.15
# 2                                3.48                  1.15
# 3                                1.16                  1.15
# 4                               12.26                  1.15
# ...

# %%
var_num=df.select_dtypes(['int64','float64'])
var_num
# Out:
#       Year  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0     1968             0.00000                             0.00
# 1     1968             2.10000                            15.61
# 2     1968             0.46800                             3.48
# 3     1968             0.15625                             1.16
# 4     1968             1.65000                            12.26
# ...    ...                 ...                              ...
# 2857  2020             7.25000                             7.25
# 2858  2020            13.50000                            13.50
# 2859  2020             8.75000                             8.75
# 2860  2020             7.25000                             7.25
# 2861  2020             5.15000                             5.15
#
#       Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                     1.15                               8.55
# 1                     1.15                               8.55
# ...

# %%
var_obj=df.select_dtypes(['object'])
var_obj
# Out:
#               State Department.Of.Labor.Uncleaned.Data Footnote
# 0           Alabama                                ...      (g)
# 1            Alaska                                2.1      (g)
# 2           Arizona                18.72 - 26.40/wk(b)      (b)
# 3          Arkansas                        1.25/day(b)      (b)
# 4        California                            1.65(b)      (b)
# ...             ...                                ...      ...
# 2857       Virginia                            7.25[c]      [c]
# 2858     Washington                               13.5      (g)
# 2859  West Virginia                               8.75      (g)
# 2860      Wisconsin                               7.25      (g)
# 2861        Wyoming                               5.15      (g)
#
# [2831 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder
# LabelEncoder()
var_obj.columns

for Col in var_obj:
    var_obj[Col]=LabelEncoder().fit_transform(var_obj[Col])

# %%
var_obj
# Out:
#       State  Department.Of.Labor.Uncleaned.Data  Footnote
# 0         0                                   0         4
# 1         1                                  80         4
# 2         2                                  70         0
# 3         3                                  29         0
# 4         4                                  44         0
# ...     ...                                 ...       ...
# 2857     49                                 236        10
# 2858     50                                  67         4
# 2859     51                                 293         4
# 2860     52                                 229         4
# 2861     53                                 169         4
#
# [2831 rows x 3 columns]

# %%
var_new=pd.concat([var_num,var_obj],axis=1)
var_new
# Out:
#       Year  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0     1968             0.00000                             0.00
# 1     1968             2.10000                            15.61
# 2     1968             0.46800                             3.48
# 3     1968             0.15625                             1.16
# 4     1968             1.65000                            12.26
# ...    ...                 ...                              ...
# 2857  2020             7.25000                             7.25
# 2858  2020            13.50000                            13.50
# 2859  2020             8.75000                             8.75
# 2860  2020             7.25000                             7.25
# 2861  2020             5.15000                             5.15
#
#       Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                     1.15                               8.55
# 1                     1.15                               8.55
# ...

# %%
var_new1=pd.concat([var_num,var_obj],axis=1)
var_new1
# Out:
#       Year  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0     1968             0.00000                             0.00
# 1     1968             2.10000                            15.61
# 2     1968             0.46800                             3.48
# 3     1968             0.15625                             1.16
# 4     1968             1.65000                            12.26
# ...    ...                 ...                              ...
# 2857  2020             7.25000                             7.25
# 2858  2020            13.50000                            13.50
# 2859  2020             8.75000                             8.75
# 2860  2020             7.25000                             7.25
# 2861  2020             5.15000                             5.15
#
#       Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                     1.15                               8.55
# 1                     1.15                               8.55
# ...
