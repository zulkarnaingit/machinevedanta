# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('placement.csv')
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                    26       1
# 1    7.46                    38       1
# 2    7.54                    40       1
# 3    6.42                     8       1
# 4    7.23                    17       0
# ..    ...                   ...     ...
# 995  8.87                    44       1
# 996  9.12                    65       1
# 997  4.89                    34       0
# 998  8.62                    46       1
# 999  4.90                    10       1
#
# [1000 rows x 3 columns]

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# cgpa                    0.0
# placement_exam_marks    0.0
# placed                  0.0
# dtype: float64

# %%
df['placement_exam_marks'].unique()
# Out:
# array([ 26,  38,  40,   8,  17,  23,  11,  39,  94,  16,   7,  43,  21,
#         19,  22,  27,  29,  47,  33,  54,  58,  46,  15,  44,   9,  12,
#         20,  86,  71,  63,  55,  10,  42,  28,  18,  36,  24,  32,  31,
#         52,  30,   3,  56,  35,   6,  76,  77,  37,   0,  51,  25,  53,
#         64,  93,   5,  41,  49,  34,  81,  50,  90,  59,  48,  45,  14,
#         57,  60,  78,  13,  62,  65,   4,  87,  68,  70,  79,  61,  66,
#         83,  75,  67,  80,  96,  74,  72,  69,   2,  97, 100], dtype=int64)

# %%
sb.scatterplot(data=df,x='cgpa',y='placed')
# Out:
# <Axes: xlabel='cgpa', ylabel='placed'>

# %%
sb.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
x = df['cgpa']
y = df['placement_exam_marks']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
X_train.shape
# Out:
# (700,)

# %%
Y_train.shape
# Out:
# (700,)

# %%
X_test.shape
# Out:
# (300,)

# %%
import numpy as np

# Assuming you have a pandas Series named 'X_train'
# Convert it to a NumPy array and then reshape it
X_train = X_train.to_numpy().reshape(-1, 1)

# Do the same for 'X_test' if needed
X_test = X_test.to_numpy().reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler     #train test performanace 3main method
#create an object for the standardScalar
ss=StandardScaler()

#applying scaling on X_train we use fit_transform()
X_train=ss.fit_transform(X_train)  # fit--- train 

#applying scaling on X_test we use transform()
X_test=ss.transform(X_test)

# %%
X_train
# Out:
# array([[-0.3798169 ],
#        [ 0.14326325],
#        [-1.00097457],
#        [-0.78847326],
#        [-0.7394345 ],
#        [ 0.53557335],
#        [ 0.64999714],
#        [-1.05001334],
#        [ 0.07787823],
#        [-0.82116577],
#        [-1.2788609 ],
#        [ 1.2384623 ],
#        [-1.0990521 ],
#        [-0.5596257 ],
#        [-0.7394345 ],
#        [ 0.86249845],
#        [ 0.79711343],
#        [ 0.53557335],
#        [-0.85385828],
#        [ 0.78076717],
#        [ 0.07787823],
#        [ 0.29037954],
#        [-1.13174461],
#        [-0.57597196],
#        [ 0.35576455],
#        [ 1.4182711 ],
#        [-0.03654555],
#        [-0.49424068],
#        [-0.42885566],
#        [-0.26539312],
#        [ 0.58461212],
#        [-0.82116577],
#        [ 0.45384208],
#        [-1.39328468],
#        [-0.26539312],
#        [ 1.0586535 ],
#        [-0.31443188],
#        [-2.01444236],
#        [-1.16443712],
#        [ 1.56538739],
#        [-0.54327945],
# ...

# %%
X_test
# Out:
# array([[-0.33077814],
#        [-2.37405996],
#        [-0.62501072],
#        [ 0.19230201],
#        [-1.60578599],
#        [-0.13462308],
#        [ 0.35576455],
#        [ 0.27403328],
#        [-0.3798169 ],
#        [ 2.05577503],
#        [-0.60866446],
#        [ 1.12403852],
#        [-0.21635435],
#        [-1.16443712],
#        [-0.46154817],
#        [ 1.10769226],
#        [-0.24904686],
#        [-0.46154817],
#        [-1.19712963],
#        [ 0.89519095],
#        [-1.19712963],
#        [-1.2788609 ],
#        [ 1.00961474],
#        [ 0.3394183 ],
#        [-1.96540359],
#        [ 0.04518572],
#        [-1.68751726],
#        [-0.46154817],
#        [-0.60866446],
#        [ 0.60095837],
#        [ 1.38557859],
#        [ 0.24134077],
#        [ 0.84615219],
#        [-0.23270061],
#        [ 1.71250368],
#        [ 0.25768703],
#        [ 2.00673626],
#        [ 0.01249321],
#        [ 1.10769226],
#        [ 1.76154245],
#        [-0.03654555],
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-0.99196729])

# %%
lr.intercept_
# Out:
# 32.14714285714286

# %%
ypred=lr.predict(X_test)

# %%
dict={"Actualouput":Y_test,"PRedicte op":ypred}
dd=pd.DataFrame(dict)
dd
# Out:
#      Actualouput  PRedicte op
# 507           75    32.475264
# 818           62    34.502133
# 452           42    32.767133
# 368           32    31.956386
# 242           44    33.740030
# ..           ...          ...
# 459           79    32.718488
# 415           46    33.123862
# 61            86    31.275358
# 347           34    31.713161
# 349           16    30.286246
#
# [300 rows x 2 columns]
