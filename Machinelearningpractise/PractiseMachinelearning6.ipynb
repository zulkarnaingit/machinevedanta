# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('laptopdata.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0          float64
# Company              object
# TypeName             object
# Inches               object
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', nan, 'Chuwi',
#        'MSI', 'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
df['Company'].value_counts()
# Out:
# Lenovo       290
# Dell         287
# HP           266
# Asus         156
# Acer         103
# MSI           53
# Toshiba       47
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# LG             3
# Huawei         2
# Fujitsu        2
# Name: Company, dtype: int64

# %%
# df.isnull().sum()

# %%
df['Company'].replace(np.nan,'Lenovo',inplace=True)

# %%
df['TypeName'].value_counts()
# Out:
# Notebook              710
# Gaming                203
# Ultrabook             191
# 2 in 1 Convertible    116
# Workstation            29
# Netbook                24
# Name: TypeName, dtype: int64

# %%
df['TypeName'].replace(np.nan,'Notebook',inplace=True)

# %%
df['Inches'].unique()
# Out:
# array(['13.3', '15.6', '15.4', '14', '12', nan, '17.3', '13.5', '12.5',
#        '13', '18.4', '13.9', '11.6', '25.6', '35.6', '12.3', '27.3', '24',
#        '33.5', '?', '31.6', '17', '15', '14.1', '11.3', '10.1'],
#       dtype=object)

# %%
df['Inches'].value_counts()
# Out:
# 15.6    640
# 14      192
# 17.3    162
# 13.3    161
# 12.5     38
# 11.6     31
# 12        6
# 13.9      6
# 13.5      5
# 12.3      5
# 15.4      4
# 15        4
# 35.6      3
# 10.1      3
# 24        2
# 13        2
# 18.4      1
# 27.3      1
# 33.5      1
# ?         1
# 31.6      1
# 17        1
# 14.1      1
# 11.3      1
# 25.6      1
# Name: Inches, dtype: int64

# %%
df['Inches'].replace('?',np.nan,inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Inches']=df['Inches'].astype('float')

# %%
df.dtypes
# Out:
# Unnamed: 0          float64
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
a=df['Inches'].mean()
a
# Out:
# 15.130817610062895

# %%
df['Inches'].fillna(a,inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['ScreenResolution'].unique()
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080', nan,
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800', 'Touchscreen 2256x1504',
#        'Quad HD+ / Touchscreen 3200x1800', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Full HD 2160x1440',
#        '4K Ultra HD / Touchscreen 3840x2160', '1600x900',
#        'IPS Panel 4K Ultra HD 3840x2160', '4K Ultra HD 3840x2160',
#        'Touchscreen 1366x768', 'Touchscreen 2560x1440',
#        'IPS Panel Full HD 1366x768', 'IPS Panel 2560x1440',
#        'IPS Panel Full HD 2560x1440',
#        'IPS Panel Retina Display 2736x1824', 'Touchscreen 2400x1600',
#        '2560x1440', 'IPS Panel Quad HD+ 2560x1440',
# ...

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                495
# 1366x768                                         274
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         52
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  14
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160                9
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# Touchscreen 2560x1440                              6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          30
# Company              0
# TypeName             0
# Inches               0
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df['ScreenResolution'].replace(np.nan,'Full HD 1920x1080',inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     128
# Intel Core i7 8550U 1.8GHz      72
# Intel Core i5 8250U 1.6GHz      68
#                               ...
# AMD A9-Series 9420 2.9GHz        1
# Intel Core i7 2.2GHz             1
# AMD A6-Series 7310 2GHz          1
# Intel Atom Z8350 1.92GHz         1
# AMD E-Series 9000e 1.5GHz        1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu'].replace(np.nan,'Intel Core i5 7200U 2.5GHz',inplace=True)

# %%
df['Ram'].value_counts()
# Out:
# 8GB     601
# 4GB     367
# 16GB    194
# 6GB      40
# 12GB     25
# 2GB      22
# 32GB     17
# 64GB      3
# 24GB      3
# 1GB       1
# Name: Ram, dtype: int64

# %%
df['Ram'].replace(np.nan,'8GB',inplace=True)

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        401
# 1TB HDD                          217
# 500GB HDD                        130
# 512GB SSD                        116
# 128GB SSD +  1TB HDD              92
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              71
# 32GB Flash Storage                37
# 2TB HDD                           16
# 64GB Flash Storage                14
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           13
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          4
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  500GB HDD             2
# ...

# %%
df['Memory'].replace('?','256GB SSD',inplace=True)

# %%
df['Memory'].replace(np.nan,'256GB SSD',inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Unnamed: 0          2.302379
# Company             0.000000
# TypeName            0.000000
# Inches              0.000000
# ScreenResolution    0.000000
# Cpu                 0.000000
# Ram                 0.000000
# Memory              0.000000
# Gpu                 2.302379
# OpSys               2.302379
# Weight              2.302379
# Price               2.302379
# dtype: float64

# %%
df['Gpu'].unique()
# Out:
# array(['Intel Iris Plus Graphics 640', 'Intel HD Graphics 6000',
#        'Intel HD Graphics 620', 'AMD Radeon Pro 455',
#        'Intel Iris Plus Graphics 650', 'AMD Radeon R5',
#        'Intel Iris Pro Graphics', 'Nvidia GeForce MX150',
#        'Intel UHD Graphics 620', 'Intel HD Graphics 520',
#        'AMD Radeon Pro 555', 'AMD Radeon R5 M430',
#        'Intel HD Graphics 615', 'AMD Radeon Pro 560',
#        'Nvidia GeForce 940MX', nan, 'Nvidia GeForce GTX 1050',
#        'AMD Radeon R2', 'AMD Radeon 530', 'Nvidia GeForce 930MX',
#        'Intel HD Graphics', 'Intel HD Graphics 500',
#        'Nvidia GeForce 930MX ', 'Nvidia GeForce GTX 1060',
#        'Nvidia GeForce 150MX', 'Intel Iris Graphics 540',
#        'AMD Radeon RX 580', 'Nvidia GeForce 920MX',
#        'AMD Radeon R4 Graphics', 'AMD Radeon 520',
#        'Nvidia GeForce GTX 1070', 'Nvidia GeForce GTX 1050 Ti',
#        'Intel HD Graphics 400', 'Nvidia GeForce MX130', 'AMD R4 Graphics',
# ...

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      271
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      66
# Nvidia GeForce GTX 1050     64
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu'].replace(np.nan,'Intel HD Graphics 620',inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1047
# No OS             63
# Linux             61
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            1
# Name: OpSys, dtype: int64

# %%
df['OpSys'].replace(np.nan,'Windows 10',inplace=True)

# %%
df['Weight'].value_counts()
# Out:
# 2.2kg     111
# 2.1kg      57
# 2.4kg      43
# 2.3kg      41
# 2.5kg      37
#          ...
# 1.41kg      1
# 3.6kg       1
# 4.7kg       1
# 4.33kg      1
# 4.0kg       1
# Name: Weight, Length: 189, dtype: int64

# %%
df['Weight'].replace(np.nan,'2.2kg',inplace=True)

# %%
df['Price'].value_counts()
# Out:
# 79866.720    14
# 95850.720    14
# 58554.720    14
# 69210.720    11
# 63882.720    11
#              ..
# 16197.120     1
# 40439.520     1
# 98994.240     1
# 61485.120     1
# 28992.312     1
# Name: Price, Length: 777, dtype: int64

# %%
d=df['Price'].mean()

# %%
df['Price'].fillna(d,inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
sb.boxplot(data=df,x='Price')
# Out:
# <Axes: xlabel='Price'>

# %%
#check the outlier in the given dataset with make coloumn
plt.figure(figsize=(20,10))

sb.boxplot(data=df,x='Price',y='Company')
plt.show()

# %%
df[(df['Company']=='Samsung')&(df['Price']<50000)]
# Out:
#       Company            TypeName  Inches                 ScreenResolution  \
# 430   Samsung             Netbook    11.6                         1366x768
# 1191  Samsung  2 in 1 Convertible    12.3  IPS Panel Touchscreen 2400x1600
#
#                                        Cpu  Ram              Memory  \
# 430   Intel Celeron Dual Core N3060 1.6GHz  4GB  16GB Flash Storage
# 1191         Samsung Cortex A72&A53 2.0GHz  4GB  32GB Flash Storage
#
#                         Gpu      OpSys  Weight     Price
# 430   Intel HD Graphics 400  Chrome OS  1.15kg  14332.32
# 1191      ARM Mali T860 MP4  Chrome OS  1.15kg  35111.52

# %%
a=df[(df['Company']=='Samsung')&(df['Price']<50000)].index

# %%
df.drop(a,inplace=True)

# %%
plt.figure(figsize=(20,10))
sb.boxplot(data=df,x='Price',y='Company')
plt.show()

# %%
df[(df['Company']=='Acer')&(df['Price']>80000)].index
# Out:
# Int64Index([730, 788, 1189], dtype='int64')

# %%
b=df[(df['Company']=='Acer')&(df['Price']>80000)].index
b
# Out:
# Int64Index([730, 788, 1189], dtype='int64')

# %%
df.drop(b,inplace=True)

# %%
plt.figure(figsize=(20,10))
sb.boxplot(data=df,x='Price',y='Company')
plt.show()

# %%
df[(df['Company'] == 'Toshiba') & (df['Price'] > 130000)]
# Out:
#      Company   TypeName  Inches                 ScreenResolution  \
# 491  Toshiba  Ultrabook    13.3  Full HD / Touchscreen 1920x1080
#
#                             Cpu   Ram     Memory                    Gpu  \
# 491  Intel Core i7 7500U 2.7GHz  32GB  512GB SSD  Intel HD Graphics 620
#
#           OpSys  Weight      Price
# 491  Windows 10  1.05kg  149130.72

# %%
c=df[(df['Company'] == 'Toshiba') & (df['Price'] > 130000)].index
c
# Out:
# Int64Index([491], dtype='int64')

# %%
df.drop(c,inplace=True)

# %%
plt.figure(figsize=(20,10))
sb.boxplot(data=df,x='Price',y='Company')
plt.show()

# %%
df[(df['Company'] == 'Lenovo') & (df['Price'] > 140000)]
# Out:
#      Company     TypeName  Inches                 ScreenResolution  \
# 563   Lenovo     Notebook    17.3      IPS Panel Full HD 1920x1080
# 577   Lenovo       Gaming    17.3      IPS Panel Full HD 1920x1080
# 610   Lenovo     Notebook    15.6  IPS Panel 4K Ultra HD 3840x2160
# 744   Lenovo  Workstation    15.6  IPS Panel 4K Ultra HD 3840x2160
# 1017  Lenovo     Notebook    17.3  IPS Panel 4K Ultra HD 3840x2160
# 1081  Lenovo       Gaming    17.3      IPS Panel Full HD 1920x1080
# 1116  Lenovo       Gaming    17.3      IPS Panel Full HD 1920x1080
#
#                                 Cpu   Ram                     Memory  \
# 563     Intel Core i7 7700HQ 2.8GHz   8GB                  256GB SSD
# 577     Intel Core i7 6820HK 2.7GHz  32GB       256GB SSD +  1TB HDD
# 610   Intel Xeon E3-1535M v6 3.1GHz  32GB                    1TB SSD
# 744      Intel Core i7 7600U 2.8GHz  16GB                    1TB SSD
# 1017    Intel Core i7 6820HQ 2.7GHz  16GB                  512GB SSD
# ...

# %%
q=df[(df['Company'] == 'Lenovo') & (df['Price'] > 140000)].index
q
# Out:
# Int64Index([563, 577, 610, 744, 1017, 1081, 1116], dtype='int64')

# %%
df.drop(q,inplace=True)

# %%
plt.figure(figsize=(20,10))
sb.boxplot(data=df,x='Price',y='Company')
plt.show()

# %%
df[(df['Company'] == 'Dell') & (df['Price'] > 140000)]
# Out:
#      Company     TypeName  Inches                     ScreenResolution  \
# 204     Dell  Workstation    15.6                4K Ultra HD 3840x2160
# 297     Dell  Workstation    17.3                    Full HD 1920x1080
# 329     Dell     Notebook    15.6  4K Ultra HD / Touchscreen 3840x2160
# 398     Dell  Workstation    15.6  4K Ultra HD / Touchscreen 3840x2160
# 424     Dell       Gaming    27.3                  IPS Panel 2560x1440
# 530     Dell       Gaming    17.3          IPS Panel Full HD 1920x1080
# 552     Dell       Gaming    17.3          IPS Panel Full HD 1920x1080
# 659     Dell       Gaming    17.3      IPS Panel 4K Ultra HD 3840x2160
# 685     Dell       Gaming    15.6                    Full HD 1920x1080
# 723     Dell       Gaming    17.3                4K Ultra HD 3840x2160
# 758     Dell       Gaming    15.6      IPS Panel 4K Ultra HD 3840x2160
# 780     Dell       Gaming    17.3          IPS Panel Full HD 1920x1080
# ...

# %%
w=df[(df['Company'] == 'Dell') & (df['Price'] > 140000)].index
w
# Out:
# Int64Index([ 204,  297,  329,  398,  424,  530,  552,  659,  685,  723,  758,
#              780,  835,  841,  939,  955,  968,  972, 1203],
#            dtype='int64')

# %%
df.drop(w,inplace=True)

# %%
plt.figure(figsize=(20,10))
sb.boxplot(data=df,x='Price',y='Company')


plt.show()

# %%
i=df[(df['Company'] == 'Asus') & (df['Price'] > 150000)].index

# %%
df.drop(i,inplace=True)

# %%
h=df[(df['Company'] == 'HP') & (df['Price'] > 150000)].index
h
# Out:
# Int64Index([749, 911, 1103, 1136], dtype='int64')

# %%
df.drop(h,inplace=True)

# %%
df_obj=df.select_dtypes(object)
df_obj
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
df_num=df.select_dtypes(['float64'])
df_num
# Out:
#       Inches        Price
# 0       13.3   71378.6832
# 1       13.3   47895.5232
# 2       15.6   30636.0000
# 3       15.4  135195.3360
# 4       13.3   96095.8080
# ...      ...          ...
# 1298    14.0   33992.6400
# 1299    13.3   79866.7200
# 1300    14.0   12201.1200
# 1301    15.6   40705.9200
# 1302    15.6   19660.3200
#
# [1263 rows x 2 columns]

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for Col in df_obj:
    df_obj[Col]=le.fit_transform(df_obj[Col])

# %%
df_obj
# Out:
#       Company  TypeName  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys  \
# 0           1         4                23   65    9       4   56      8
# 1           1         4                 1   63    9       2   49      8
# 2           7         3                 8   74    9      14   51      4
# 3           1         4                25   85    1      26    8      8
# 4           1         4                23   67    9      14   57      8
# ...       ...       ...               ...  ...  ...     ...  ...    ...
# 1298       10         0                13   89    6       4   45      5
# 1299       10         0                19   89    1      26   45      5
# 1300       10         3                 0   34    4      31   38      5
# 1301        7         3                 0   89    8      10   20      5
# 1302        2         3                 0   34    6      23   38      5
#
#       Weight
# 0         39
# 1         36
# 2         75
# 3         72
# 4         39
# ...      ...
# ...

# %%
df_sum=pd.concat([df_obj,df_num],axis=1)
df_sum
# Out:
#       Company  TypeName  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys  \
# 0           1         4                23   65    9       4   56      8
# 1           1         4                 1   63    9       2   49      8
# 2           7         3                 8   74    9      14   51      4
# 3           1         4                25   85    1      26    8      8
# 4           1         4                23   67    9      14   57      8
# ...       ...       ...               ...  ...  ...     ...  ...    ...
# 1298       10         0                13   89    6       4   45      5
# 1299       10         0                19   89    1      26   45      5
# 1300       10         3                 0   34    4      31   38      5
# 1301        7         3                 0   89    8      10   20      5
# 1302        2         3                 0   34    6      23   38      5
#
#       Weight  Inches        Price
# 0         39    13.3   71378.6832
# ...

# %%
sb.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >
