# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('placement.csv')
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                    26       1
# 1    7.46                    38       1
# 2    7.54                    40       1
# 3    6.42                     8       1
# 4    7.23                    17       0
# ..    ...                   ...     ...
# 995  8.87                    44       1
# 996  9.12                    65       1
# 997  4.89                    34       0
# 998  8.62                    46       1
# 999  4.90                    10       1
#
# [1000 rows x 3 columns]

# %%
sb.scatterplot(data=df,x='cgpa',y='placement_exam_marks')
# Out:
# <Axes: xlabel='cgpa', ylabel='placement_exam_marks'>
