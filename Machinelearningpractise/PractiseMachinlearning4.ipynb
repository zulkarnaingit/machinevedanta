# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('unclean focus.csv')
df
# Out:
#        model    year     price transmission mileage fuel type engine size  \
# 0      Focus  2016.0    £8,000       Manual     NaN    Petrol       0.999
# 1      Focus  2019.0   £13,400       Manual     NaN    Petrol       0.999
# 2      Focus  2019.0   £14,600       Manual     NaN    Petrol       1.498
# 3      Focus  2016.0    £9,450       Manual     NaN    Diesel        1.56
# 4      Focus  2015.0    £9,999       Manual     NaN    Diesel        1.56
# ...      ...     ...       ...          ...     ...       ...         ...
# 5599   Focus  2019.0   £18,745       Manual     NaN    Diesel           2
# 5600   Focus  2019.0   £16,350       Manual     NaN    Petrol           1
# 5601   Focus  2019.0   £16,850       Manual     NaN    Petrol           1
# 5602   Focus  2019.0   £17,310    Automatic     NaN    Petrol           1
# 5603   Focus  2019.0   £17,610    Automatic     NaN    Petrol           1
#
#      mileage2 fuel type2 engine size2     reference
# ...

# %%
df.dtypes
# Out:
# model            object
# year            float64
# price            object
# transmission     object
# mileage          object
# fuel type        object
# engine size      object
# mileage2         object
# fuel type2       object
# engine size2     object
# reference        object
# dtype: object

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['price'].unique()
# Out:
# array([' £8,000', ' £13,400', ' £14,600', ..., ' £6,494', ' £8,200',
#        ' £17,799'], dtype=object)

# %%
df['price'].value_counts()
# Out:
#  £11,000    74
#  £16,000    67
#  £13,000    51
#  £12,000    50
#  £18,500    47
#             ..
#  £9,940      1
#  £6,591      1
#  £18,090     1
#  £9,677      1
#  £17,799     1
# Name: price, Length: 1768, dtype: int64

# %%
df['price'].replace(' ...',' £11,000',inplace=True)

# %%
df['price'].unique()
# Out:
# array([' £8,000', ' £13,400', ' £14,600', ..., ' £6,494', ' £8,200',
#        ' £17,799'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2016., 2019., 2015., 2018., 2020., 2017., 2013., 2009., 2011.,
#        2014.,   nan, 2012., 2008., 2006., 2010., 2007., 2003., 2005.,
#        2002.])

# %%
df['year'].value_counts()
# Out:
# 2019.0    1594
# 2017.0    1288
# 2018.0    1066
# 2016.0     553
# 2015.0     393
# 2014.0     156
# 2013.0     152
# 2020.0      66
# 2012.0      42
# 2009.0      37
# 2011.0      32
# 2008.0      26
# 2010.0      20
# 2007.0      15
# 2005.0      11
# 2003.0       4
# 2006.0       3
# 2002.0       1
# Name: year, dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# model            0.999286
# year             2.587438
# price            0.999286
# transmission     0.999286
# mileage         15.613847
# fuel type       60.956460
# engine size      1.802284
# mileage2         1.695218
# fuel type2      15.613847
# engine size2    15.613847
# reference        0.999286
# dtype: float64

# %%
f=df['year'].mean()
f
# Out:
# 2017.1060633815716

# %%
df['year'].fillna(f,inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# model            object
# year            float64
# price            object
# transmission     object
# mileage          object
# fuel type        object
# engine size      object
# mileage2         object
# fuel type2       object
# engine size2     object
# reference        object
# dtype: object

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# model            0.999286
# year             0.000000
# price            0.999286
# transmission     0.999286
# mileage         15.613847
# fuel type       60.956460
# engine size      1.802284
# mileage2         1.695218
# fuel type2      15.613847
# engine size2    15.613847
# reference        0.999286
# dtype: float64

# %%
df['mileage'] = df['mileage'].str.replace(',', '')

# %%
df['mileage'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 5599    NaN
# 5600    NaN
# 5601    NaN
# 5602    NaN
# 5603    NaN
# Name: mileage, Length: 5604, dtype: object>

# %%
df.dtypes
# Out:
# model            object
# year            float64
# price            object
# transmission     object
# mileage          object
# fuel type        object
# engine size      object
# mileage2         object
# fuel type2       object
# engine size2     object
# reference        object
# dtype: object

# %%
df['mileage'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df['mileage'].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
# ...

# %%
df['mileage'].unique()
# Out:
# array([nan, '13255', '42112', ..., '21215', '1478', '9137'], dtype=object)

# %%
df['mileage'] = pd.to_numeric(df['mileage'], errors='coerce')

# %%
df.dtypes

# %%
d=df['mileage'].mean()
d
# Out:
# 24017.563028764805

# %%
df.isnull().sum()/df.shape[0]*100
# df['mileage'].fillna(d,inplace=True)
# Out:
# model            0.999286
# year             0.000000
# price            0.999286
# transmission     0.999286
# mileage         15.631692
# fuel type       60.956460
# engine size      1.802284
# mileage2         1.695218
# fuel type2      15.613847
# engine size2    15.613847
# reference        0.999286
# dtype: float64

# %%
d=df['mileage'].mean()

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['mileage'].replace(np.nan,d,inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.head(1000)

# %%
df['fuel type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, '11', '14', '26', '12', '24', '10', '13',
#        '15', '33', '36', '35', '16', '22', '40', '8', '21', '9', '20',
#        '7', '19', '34', '18', '25', '17', '31', '38', '6'], dtype=object)

# %%
df['fuel type'].value_counts()
# Out:
# Petrol    539
# 14        425
# Diesel    280
# 11        197
# 15        153
# 26        140
# 24         86
# 16         79
# 12         69
# 36         53
# 10         44
# 13         24
# 22         23
# 33         16
# 40         11
# 35          9
# 21          7
# 18          6
# 19          5
# 9           4
# 34          4
# 17          4
# 8           2
# 20          2
# 25          2
# 7           1
# 31          1
# 38          1
# 6           1
# Name: fuel type, dtype: int64

# %%
df['fuel type'].replace(np.nan,'Petrol',inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.duplicated().sum()
# Out:
# 55

# %%
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# model            object
# year            float64
# price            object
# transmission     object
# mileage         float64
# fuel type        object
# engine size      object
# mileage2         object
# fuel type2       object
# engine size2     object
# reference        object
# dtype: object

# %%
df['engine size']
# Out:
# 0       0.999
# 1       0.999
# 2       1.498
# 3        1.56
# 4        1.56
#         ...
# 5599        2
# 5600        1
# 5601        1
# 5602        1
# 5603        1
# Name: engine size, Length: 5549, dtype: object

# %%
df['engine size'].unique()
# Out:
# array(['0.999', '1.498', '1.56', '999', '1000', '2300', '1498', '1.5',
#        '£145', '£20', '£0', '£165', '£150', '£125', '2', '1', '£30',
#        '£205', '2.3', '£235', '£160', '£145  ', '£150  ', '£200', '£240',
#        nan, '£260', '£120', '£140', '1596', '1499', '£300', '£195',
#        '£325', '1999', '1.6', '1560', '£190', '£265', '£330', '£155',
#        '£230', ' 2,00 cc'], dtype=object)

# %%
df['engine size'].value_counts()
# Out:
# £145        2582
# £20          693
# £0           511
# 1            418
# £150         388
# 1.5          213
# £125         117
# 2            116
# £200         101
# £30           93
# £160          46
# £235          37
# 2.3           37
# £145          28
# £205          26
# £165          21
# 1499           9
# £260           8
# £240           7
# 1560           5
# £265           5
# £150           5
# 1.6            4
# 999            4
# £325           4
# £140           3
# 1999           2
# £330           2
# £195           2
# 0.999          2
# 1596           2
# 1.56           2
# £300           1
# £120           1
# 1.498          1
# 1498           1
# 2300           1
# £190           1
# 1000           1
# £155           1
# £230           1
#  2,00 cc       1
# Name: engine size, dtype: int64

# %%
df['engine size'].replace(np.nan,'£145',inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# model            object
# year            float64
# price            object
# transmission     object
# mileage         float64
# fuel type        object
# engine size      object
# mileage2         object
# fuel type2       object
# engine size2     object
# reference        object
# dtype: object

# %%
df.head()
# Out:
#     model    year     price transmission       mileage fuel type engine size  \
# 0   Focus  2016.0    £8,000       Manual  24017.563029    Petrol       0.999
# 1   Focus  2019.0   £13,400       Manual  24017.563029    Petrol       0.999
# 2   Focus  2019.0   £14,600       Manual  24017.563029    Petrol       1.498
# 3   Focus  2016.0    £9,450       Manual  24017.563029    Diesel        1.56
# 4   Focus  2015.0    £9,999       Manual  24017.563029    Diesel        1.56
#
#   mileage2 fuel type2 engine size2     reference
# 0   38,852        NaN          NaN  /ad/25451236
# 1   11,952        NaN          NaN  /ad/25466927
# 2   22,142        NaN          NaN  /ad/25484363
# 3   14,549        NaN          NaN  /ad/20444868
# 4    7,010        NaN          NaN  /ad/22551057

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# model            0.018021
# year             0.000000
# price            0.018021
# transmission     0.018021
# mileage          0.000000
# fuel type        0.000000
# engine size      0.000000
# mileage2         0.720851
# fuel type2      14.777437
# engine size2    14.777437
# reference        0.018021
# dtype: float64

# %%
df['fuel type2'].unique()
# Out:
# array([nan, 'Petrol', 'Diesel', 'Other'], dtype=object)

# %%
df['fuel type2'].value_counts()
# Out:
# Petrol    3067
# Diesel    1661
# Other        1
# Name: fuel type2, dtype: int64

# %%
df['fuel type2'].replace(np.nan,'Petrol',inplace=True)

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# model            0.018021
# year             0.000000
# price            0.018021
# transmission     0.018021
# mileage          0.000000
# fuel type        0.000000
# engine size      0.000000
# mileage2         0.720851
# fuel type2       0.000000
# engine size2    14.777437
# reference        0.018021
# dtype: float64

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['engine size2'].unique()
# Out:
# array([nan, '0.999', '1.499', '1.596', '1.997', '1', '1000', '1500',
#        '1.498', '2', '1.6', '1.5', '1.56', '1.8', '1600', '1999', '2.3',
#        '1596', '1798', '999', '1560', '1498', '998', '1997', '1499',
#        '1560 cc', '2000', '1988', '2521', '2261', '0', '2300', '0.998',
#        '1496', '1753', '1989', '2.5', '1596 cc', '2.29', 'Unknown',
#        '2.521', '1388', '1.0T'], dtype=object)

# %%
df['engine size2'].value_counts()
# Out:
# 1          1972
# 1.5        1090
# 2           705
# 1.6         228
# 999         155
# 1499        100
# 1000         67
# 1596         63
# 2.3          58
# 1560         40
# 1997         38
# 1999         30
# 1498         26
# 1500         23
# 0.999        18
# 1.499        18
# 998          13
# 0            12
# 1600         10
# 1753          7
# 2000          6
# Unknown       5
# 1798          5
# 1.8           4
# 1.56          4
# 2300          4
# 1.596         3
# 1.498         3
# 2.5           3
# 1496          3
# 1.997         3
# 2261          2
# 1989          2
# 0.998         1
# 1560 cc       1
# 2521          1
# 1988          1
# 1596 cc       1
# 2.29          1
# 2.521         1
# 1388          1
# 1.0T          1
# Name: engine size2, dtype: int64

# %%
df['engine size2'].replace(np.nan,'1',inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['mileage2'].unique()
# Out:
# array([3.8852e+04, 1.1952e+04, 2.2142e+04, 1.4549e+04, 7.0100e+03,
#        2.6796e+04, 1.6128e+04, 4.9000e+03, 3.0953e+04, 3.0000e+03,
#        5.7700e+01, 6.1400e+01, 7.4300e+01, 4.4800e+01, 8.0700e+01,
#        6.0100e+01, 6.7300e+01, 5.1400e+01, 8.8790e+03, 4.6980e+03,
#        1.6199e+04, 3.2120e+03, 8.2010e+03, 1.3471e+04, 1.2372e+04,
#        1.1535e+04, 2.2190e+03, 1.0230e+04, 2.0100e+02, 4.8961e+04,
#        1.3516e+04, 2.3500e+04, 1.2395e+04, 4.9840e+03, 6.3930e+03,
#        1.2198e+04, 5.0400e+01, 4.6300e+01, 9.4390e+03, 9.9430e+03,
#        8.1880e+03, 1.0589e+04, 1.5272e+04, 1.3789e+04, 3.6550e+03,
#        7.5550e+03, 1.3737e+04, 1.3706e+04, 7.4260e+03, 1.1594e+04,
#        1.2119e+04, 1.3762e+04, 1.2811e+04, 1.3797e+04, 1.1645e+04,
#        1.3545e+04, 6.4280e+03, 1.0370e+04, 5.3130e+04, 2.9705e+04,
#        5.3670e+03, 4.8550e+03, 1.0000e+02, 9.0220e+03, 1.9785e+04,
#        5.7029e+04, 6.4200e+01, 4.2200e+01, 6.5000e+04, 4.1495e+04,
# ...

# %%
df['mileage2'] = df['mileage2'].str.replace(',', '')

# %%
df
# Out:
#        model    year     price transmission       mileage fuel type  \
# 0      Focus  2016.0    £8,000       Manual  24017.563029    Petrol
# 1      Focus  2019.0   £13,400       Manual  24017.563029    Petrol
# 2      Focus  2019.0   £14,600       Manual  24017.563029    Petrol
# 3      Focus  2016.0    £9,450       Manual  24017.563029    Diesel
# 4      Focus  2015.0    £9,999       Manual  24017.563029    Diesel
# ...      ...     ...       ...          ...           ...       ...
# 5599   Focus  2019.0   £18,745       Manual  24017.563029    Diesel
# 5600   Focus  2019.0   £16,350       Manual  24017.563029    Petrol
# 5601   Focus  2019.0   £16,850       Manual  24017.563029    Petrol
# 5602   Focus  2019.0   £17,310    Automatic  24017.563029    Petrol
# 5603   Focus  2019.0   £17,610    Automatic  24017.563029    Petrol
#
#      engine size  mileage2 fuel type2 engine size2     reference
# 0          0.999   38852.0     Petrol            1  /ad/25451236
# ...
