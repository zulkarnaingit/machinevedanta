# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 0       145.08     AL
# 1       133.93     AK
# 2       110.35     AZ
# 3       142.39     AR
# 4       165.63     CA
# 5       139.91     CO
# 6       167.02     CT
# 7       151.48     DE
# 8       136.05     DC
# 9       144.18     FL
# 10      142.80     GA
# 11      120.92     HI
# 12       82.75     ID
# 13      139.15     IL
# 14      108.92     IN
# 15      114.47     IA
# 16      133.80     KS
# 17      137.13     KY
# 18      194.78     LA
# 19       96.57     ME
# 20      192.70     MD
# 21      135.63     MA
# 22      152.26     MI
# 23      133.35     MN
# 24      155.77     MS
# 25      144.45     MO
# 26       85.15     MT
# 27      114.82     NE
# 28      138.71     NV
# 29      120.21     NH
# 30      159.85     NJ
# 31      120.75     NM
# 32      150.01     NY
# 33      127.82     NC
# 34      109.72     ND
# 35      133.52     OH
# 36      178.86     OK
# 37      104.61     OR
# 38      153.86     PA
# 39      148.58     RI
# 40      116.29     SC
# 41       96.87     SD
# 42      155.57     TN
# 43      156.83     TX
# 44      109.48     UT
# 45      109.61     VT
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
df.dtypes
# Out:
# total             float64
# speeding          float64
# alcohol           float64
# not_distracted    float64
# no_previous       float64
# ins_premium       float64
# ins_losses        float64
# abbrev             object
# dtype: object

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
sb.scatterplot(data=df,x='not_distracted',y='total')
# Out:
# <Axes: xlabel='not_distracted', ylabel='total'>

# %%
sb.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
X=df[['alcohol','not_distracted','no_previous']]
Y=df['total']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
X_train.shape
# Out:
# (35, 3)

# %%
X_test.shape
# Out:
# (16, 3)

# %%
Y_train.shape
# Out:
# (35,)

# %%
Y_test.shape
# Out:
# (16,)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)

# %%
X_train
# Out:
# array([[ 2.82257755,  1.99728518,  1.39714121],
#        [ 0.373136  ,  0.77722669,  0.41207036],
#        [-0.28209109, -0.18932184, -0.56975915],
#        [ 0.26353866, -2.72598219,  0.87882245],
#        [-0.38697456, -0.43569695, -0.68644717],
#        [ 0.38079603,  0.44679418,  0.34694902],
#        [-0.05111175,  0.60331485,  0.48514771],
#        [-0.93083661, -0.65487047, -1.01411657],
#        [ 0.44914706,  0.96362452,  1.20472384],
#        [-1.31089189, -1.23479959, -1.81796738],
#        [-0.97149369, -0.68363282, -1.16027126],
#        [ 2.96340423,  2.1571503 ,  1.74926794],
#        [-0.47359181, -0.04707087, -0.24827776],
#        [-0.02400704, -0.36969964,  1.00611847],
#        [-0.65330787,  0.18592642, -0.03228705],
#        [-0.17956455, -0.00470772, -0.01902705],
#        [-0.54724593, -0.20738191, -0.50021781],
#        [-0.12653358, -0.00604551, -0.90037521],
#        [ 1.03484465,  0.21825618,  1.61254258],
#        [-0.59438457, -1.139594  , -0.66081117],
#        [ 0.27414486,  0.1841427 , -0.32223911],
#        [-0.66037867, -1.02342981, -1.69774336],
#        [-0.0876442 ,  0.02405462,  0.41855303],
#        [ 0.97533212,  2.02894606,  1.79405728],
#        [-0.28503725,  0.51368336,  0.70614775],
#        [-0.4341132 , -0.06245538,  0.15099565],
#        [ 0.37195754,  0.9056539 ,  0.12447564],
#        [-0.63857705,  0.27711865, -0.2824591 ],
#        [-0.70751731, -0.72287446, -0.50021781],
#        [ 1.27643018,  0.08113338,  0.17898899],
#        [ 0.10739192,  0.55337093,  0.6507504 ],
#        [-2.01266838, -1.80291162, -2.56877818],
#        [-0.33688975, -0.21875307,  0.11092097],
#        [ 1.39250908,  0.81780612,  0.66607307],
#        [-0.99034914, -1.20626021, -0.91275121]])

# %%
X_test
# Out:
# array([[-0.39196873,  0.16931103, -0.44528917],
#        [ 0.34297264,  0.68976516,  1.27883995],
#        [-0.03849693, -1.70166199, -0.26422975],
#        [ 2.79744352,  1.23893882,  1.36111729],
#        [ 0.34297264,  0.72899185,  0.23239039],
#        [-1.6402025 , -0.63647056, -0.44750622],
#        [-0.86559762, -0.70932013, -0.96777493],
#        [ 0.55295589,  0.33252208,  0.73787873],
#        [-0.61420101, -0.43099742, -0.69581629],
#        [ 0.34705565,  0.27718443,  0.18361519],
#        [ 0.70227731,  1.9580948 ,  2.12230588],
#        [-0.66494696, -0.60191371, -0.74804023],
#        [-0.6544478 , -0.9288028 , -0.87416598],
#        [ 1.03941709,  1.48083674,  0.99013023],
#        [-0.2344813 , -0.57389465, -0.95964573],
#        [-1.02075191, -1.29258365, -1.50380936]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([0.6270733 , 0.86299297, 2.68969999])

# %%
lr.intercept_
# Out:
# 16.29142857142857

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([14.9940554 , 20.54145583, 14.0880671 , 22.77582335, 17.76067281,
#        13.50997429, 12.53347291, 18.90980909, 13.66279471, 17.2421359 ,
#        24.12999609, 13.34300699, 12.72824733, 20.88432423, 13.06796544,
#        10.49105569])

# %%
dict={"Actual ouput":Y_test,"Predict ouput":y_pred}
cc=pd.DataFrame(dict)
cc
# Out:
#     Actual ouput  Predict ouput
# 22          14.1      14.994055
# 2           18.6      20.541456
# 49          13.8      14.088067
# 26          21.4      22.775823
# 33          16.8      17.760673
# 44          11.3      13.509974
# 30          11.2      12.533473
# 50          17.4      18.909809
# 32          12.3      13.662795
# 27          14.9      17.242136
# 3           22.4      24.129996
# 29          11.6      13.343007
# 47          10.6      12.728247
# 41          19.4      20.884324
# 39          11.1      13.067965
# 21           8.2      10.491056
