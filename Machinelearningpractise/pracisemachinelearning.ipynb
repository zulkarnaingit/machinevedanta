# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Automobile_data.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type body-style drive-wheels  \
# 200         -1                95  volvo       gas      sedan          rwd
# 201         -1                95  volvo       gas      sedan          rwd
# 202         -1                95  volvo       gas      sedan          rwd
# 203         -1                95  volvo    diesel      sedan          rwd
# 204         -1                95  volvo       gas      sedan          rwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 200           front   68.9    55.5         ohc          141        114
# 201           front   68.8    55.5         ohc          141        160
# 202           front   68.9    55.5        ohcv          173        134
# 203           front   68.9    55.5         ohc          145        106
# 204           front   68.9    55.5         ohc          141        114
#
#      city-mpg  highway-mpg  price
# 200        23           28  16845
# ...

# %%
df.shape
# Out:
# (205, 15)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
sb.heatmap(df.isnull())
plt.show()

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df['normalized-losses'].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
df['normalized-losses'].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
import numpy as np
df['normalized-losses'].replace('?',np.nan)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object

# %%
df['normalized-losses'].replace('?',np.nan,inplace=True)

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df['normalized-losses'].unique()
# Out:
# array([nan, '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
rr=pd.DataFrame(df)
rr
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3               NaN  alfa-romero       gas  convertible
# 1            3               NaN  alfa-romero       gas  convertible
# 2            1               NaN  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
rr.to_csv('rrr.csv',index='False',encoding='utf-8')

# %%
oo=pd.read_csv('rrr.csv')
oo
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                NaN  alfa-romero       gas
# 1             1          3                NaN  alfa-romero       gas
# 2             2          1                NaN  alfa-romero       gas
# 3             3          2              164.0         audi       gas
# 4             4          2              164.0         audi       gas
# ..          ...        ...                ...          ...       ...
# 200         200         -1               95.0        volvo       gas
# 201         201         -1               95.0        volvo       gas
# 202         202         -1               95.0        volvo       gas
# 203         203         -1               95.0        volvo    diesel
# 204         204         -1               95.0        volvo       gas
#
#       body-style drive-wheels engine-location  width  height engine-type  \
# ...

# %%
oo.dtypes
# Out:
# Unnamed: 0             int64
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
class1={
    'CLASS':['A','B','C','D','E','F','G','H','I','J'],
    'PERCENT':['?',78,56,44,'?','?',43,'?',67,'?'],
    'MARKS':[56,78,'?',45,'?',65,90,'?','?','?'],
    
    
}

gg=pd.DataFrame(class1)
gg
# Out:
#   CLASS PERCENT MARKS
# 0     A       ?    56
# 1     B      78    78
# 2     C      56     ?
# 3     D      44    45
# 4     E       ?     ?
# 5     F       ?    65
# 6     G      43    90
# 7     H       ?     ?
# 8     I      67     ?
# 9     J       ?     ?

# %%
gg.head()
# Out:
#   CLASS PERCENT MARKS
# 0     A       ?    56
# 1     B      78    78
# 2     C      56     ?
# 3     D      44    45
# 4     E       ?     ?

# %%
gg.tail()
# Out:
#   CLASS PERCENT MARKS
# 5     F       ?    65
# 6     G      43    90
# 7     H       ?     ?
# 8     I      67     ?
# 9     J       ?     ?

# %%
gg.dtypes
# Out:
# CLASS      object
# PERCENT    object
# MARKS      object
# dtype: object

# %%
gg.isnull()
# Out:
#    CLASS  PERCENT  MARKS
# 0  False    False  False
# 1  False    False  False
# 2  False    False  False
# 3  False    False  False
# 4  False    False  False
# 5  False    False  False
# 6  False    False  False
# 7  False    False  False
# 8  False    False  False
# 9  False    False  False

# %%
gg.isnull().sum()
# Out:
# CLASS      0
# PERCENT    0
# MARKS      0
# dtype: int64

# %%
gg.shape
# Out:
# (10, 3)

# %%
sb.heatmap(gg.isnull())
plt.show()

# %%
gg.dtypes
# Out:
# CLASS      object
# PERCENT    object
# MARKS      object
# dtype: object

# %%
gg['PERCENT'].unique()
# Out:
# array(['?', 78, 56, 44, 43, 67], dtype=object)

# %%
gg['PERCENT'].value_counts()
# Out:
# ?     5
# 78    1
# 56    1
# 44    1
# 43    1
# 67    1
# Name: PERCENT, dtype: int64

# %%
gg['PERCENT'].replace('?',np.nan)
# Out:
# 0     NaN
# 1    78.0
# 2    56.0
# 3    44.0
# 4     NaN
# 5     NaN
# 6    43.0
# 7     NaN
# 8    67.0
# 9     NaN
# Name: PERCENT, dtype: float64

# %%
gg['PERCENT'].replace('?',np.nan,inplace=True)

# %%
gg['MARKS'].replace('?',np.nan,inplace=True)

# %%
gg.dtypes
# Out:
# CLASS       object
# PERCENT    float64
# MARKS      float64
# dtype: object

# %%
sb.heatmap(gg.isnull())
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Automobile_data.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type body-style drive-wheels  \
# 200         -1                95  volvo       gas      sedan          rwd
# 201         -1                95  volvo       gas      sedan          rwd
# 202         -1                95  volvo       gas      sedan          rwd
# 203         -1                95  volvo    diesel      sedan          rwd
# 204         -1                95  volvo       gas      sedan          rwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 200           front   68.9    55.5         ohc          141        114
# 201           front   68.8    55.5         ohc          141        160
# 202           front   68.9    55.5        ohcv          173        134
# 203           front   68.9    55.5         ohc          145        106
# 204           front   68.9    55.5         ohc          141        114
#
#      city-mpg  highway-mpg  price
# 200        23           28  16845
# ...

# %%
df.shape
# Out:
# (205, 15)

# %%
df['normalized-losses'].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
df.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  body-style  drive-wheels  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
sb.heatmap(df.isnull())
plt.show()

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df['normalized-losses'].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
df['normalized-losses'].replace('?',np.nan,inplace=True)
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3               NaN  alfa-romero       gas  convertible
# 1            3               NaN  alfa-romero       gas  convertible
# 2            1               NaN  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
sb.heatmap(df['horsepower'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 sb.heatmap(df['horsepower'])
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
gg=pd.read_csv('rrr.csv')
gg
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                NaN  alfa-romero       gas
# 1             1          3                NaN  alfa-romero       gas
# 2             2          1                NaN  alfa-romero       gas
# 3             3          2              164.0         audi       gas
# 4             4          2              164.0         audi       gas
# ..          ...        ...                ...          ...       ...
# 200         200         -1               95.0        volvo       gas
# 201         201         -1               95.0        volvo       gas
# 202         202         -1               95.0        volvo       gas
# 203         203         -1               95.0        volvo    diesel
# 204         204         -1               95.0        volvo       gas
#
#       body-style drive-wheels engine-location  width  height engine-type  \
# ...

# %%
car={
    'car_name':['ferrari','porsche','Buggati','lambo','mercedes','bmw','aston_martin'],
    'car_price':[4.5,2.22,'?','?',5.6,1.5,'>'],
    'car_cc':[565,'?',550,660,'?','>',340],
}
car
# Out:
# {'car_name': ['ferrari',
#   'porsche',
#   'Buggati',
#   'lambo',
#   'mercedes',
#   'bmw',
#   'aston_martin'],
#  'car_price': [4.5, 2.22, '?', '?', 5.6, 1.5, '>'],
#  'car_cc': [565, '?', 550, 660, '?', '>', 340]}

# %%
cd=pd.DataFrame(car)

# %%
cd
# Out:
#        car_name car_price car_cc
# 0       ferrari       4.5    565
# 1       porsche      2.22      ?
# 2       Buggati         ?    550
# 3         lambo         ?    660
# 4      mercedes       5.6      ?
# 5           bmw       1.5      >
# 6  aston_martin         >    340

# %%
cd.head()
# Out:
#    car_name car_price car_cc
# 0   ferrari       4.5    565
# 1   porsche      2.22      ?
# 2   Buggati         ?    550
# 3     lambo         ?    660
# 4  mercedes       5.6      ?

# %%
cd['car_price'].unique()
# Out:
# array([4.5, 2.22, '?', 5.6, 1.5, '>'], dtype=object)

# %%
cd['car_price'].value_counts()
# Out:
# ?       2
# 4.5     1
# 2.22    1
# 5.6     1
# 1.5     1
# >       1
# Name: car_price, dtype: int64

# %%
cd.isnull().sum()
# Out:
# car_name     0
# car_price    0
# car_cc       0
# dtype: int64

# %%
sb.heatmap(cd.isnull())
plt.show()

# %%
cd['car_price'].replace('?',np.nan,inplace=True)

# %%
cd['car_price'].replace('>',np.nan,inplace=True)

# %%
cd['car_cc'].replace('?',np.nan,inplace=True)
cd['car_cc'].replace('>',np.nan,inplace=True)

# %%
sb.heatmap(cd.isnull())
# Out:
# <Axes: >

# %%
cd
# Out:
#        car_name  car_price  car_cc
# 0       ferrari       4.50   565.0
# 1       porsche       2.22     NaN
# 2       Buggati        NaN   550.0
# 3         lambo        NaN   660.0
# 4      mercedes       5.60     NaN
# 5           bmw       1.50     NaN
# 6  aston_martin        NaN   340.0

# %%
cd.dtypes
# Out:
# car_name      object
# car_price    float64
# car_cc       float64
# dtype: object

# %%
cd.isnull().sum()
# Out:
# car_name     0
# car_price    3
# car_cc       3
# dtype: int64

# %%
sb.lineplot(data=cd,x='car_name',y='car_price')
plt.xticks['car_name']
plt.yticks['car_price']
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 sb.lineplot(data=cd,x='car_name',y='car_price')
# ----> 2 plt.xticks['car_name']
#       3 plt.yticks['car_price']
#       4 plt.show()
#
# TypeError: 'function' object is not subscriptable

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
gg=pd.read_csv('Automobile_data.csv')

# %%
gg
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
gg.shape
# Out:
# (205, 15)

# %%
gg.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  body-style  drive-wheels  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
gg.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
gg.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
gg['normalized-losses'].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
gg['normalized-losses'].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
gg['normalized-losses'].replace('?',np.nan,inplace=True)

# %%
gg
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3               NaN  alfa-romero       gas  convertible
# 1            3               NaN  alfa-romero       gas  convertible
# 2            1               NaN  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
gg.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
gg['normalized-losses'].value_counts()
# Out:
# 161    11
# 91      8
# 150     7
# 128     6
# 134     6
# 104     6
# 95      5
# 102     5
# 103     5
# 74      5
# 85      5
# 168     5
# 94      5
# 65      5
# 106     4
# 122     4
# 148     4
# 118     4
# 93      4
# 101     3
# 125     3
# 137     3
# 154     3
# 83      3
# 115     3
# 119     2
# 87      2
# 194     2
# 197     2
# 108     2
# 89      2
# 164     2
# 158     2
# 145     2
# 192     2
# 188     2
# 81      2
# 110     2
# 113     2
# 129     2
# 153     2
# 107     1
# 78      1
# 186     1
# 231     1
# 77      1
# 98      1
# 121     1
# 90      1
# 142     1
# 256     1
# Name: normalized-losses, dtype: int64

# %%
sb.heatmap(gg.isnull())
plt.show()

# %%
gg['normalized-losses']=gg['normalized-losses'].astype('float')

# %%
gg.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
gg.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3                NaN  alfa-romero       gas  convertible
# 1          3                NaN  alfa-romero       gas  convertible
# 2          1                NaN  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# ...

# %%
gg.isnull().sum()/gg.shape[0]*100
# Out:
# symboling             0.0
# normalized-losses    20.0
# make                  0.0
# fuel-type             0.0
# body-style            0.0
# drive-wheels          0.0
# engine-location       0.0
# width                 0.0
# height                0.0
# engine-type           0.0
# engine-size           0.0
# horsepower            0.0
# city-mpg              0.0
# highway-mpg           0.0
# price                 0.0
# dtype: float64

# %%
# Out:
# symboling              0.000000
# normalized-losses    273.333333
# make                   0.000000
# fuel-type              0.000000
# body-style             0.000000
# drive-wheels           0.000000
# engine-location        0.000000
# width                  0.000000
# height                 0.000000
# engine-type            0.000000
# engine-size            0.000000
# horsepower             0.000000
# city-mpg               0.000000
# highway-mpg            0.000000
# price                  0.000000
# dtype: float64

# %%
m=gg['normalized-losses'].mean()
print(m)
# Out:
# 122.0

# %%
gg['normalized-losses'].fillna(m,inplace=True)

# %%
gg.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# ...

# %%
sb.heatmap(gg.isnull())
plt.show()

# %%
gg.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
gg.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# ...

# %%
gg['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', '?', '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
gg['horsepower'].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 62      6
# 101     6
# 160     6
# 114     6
# 84      5
# 97      5
# 102     5
# 145     5
# 82      5
# 76      5
# 111     4
# 92      4
# 123     4
# 86      4
# 90      3
# 73      3
# 85      3
# 207     3
# 182     3
# 121     3
# 152     3
# 112     2
# 56      2
# 161     2
# 156     2
# 94      2
# 52      2
# ?       2
# 162     2
# 155     2
# 184     2
# 100     2
# 176     2
# 55      1
# 262     1
# 134     1
# 115     1
# 140     1
# 48      1
# 58      1
# 60      1
# 78      1
# 135     1
# 200     1
# 64      1
# 120     1
# 72      1
# 154     1
# 288     1
# 143     1
# 142     1
# 175     1
# 106     1
# Name: horsepower, dtype: int64

# %%
gg['horsepower'].replace('?',np.nan,inplace=True)

# %%
gg['horsepower'].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 114     6
# 160     6
# 101     6
# 62      6
# 88      6
# 145     5
# 76      5
# 97      5
# 82      5
# 84      5
# 102     5
# 92      4
# 111     4
# 123     4
# 86      4
# 207     3
# 182     3
# 90      3
# 121     3
# 152     3
# 85      3
# 73      3
# 161     2
# 94      2
# 56      2
# 112     2
# 184     2
# 155     2
# 156     2
# 52      2
# 100     2
# 162     2
# 176     2
# 140     1
# 115     1
# 134     1
# 78      1
# 48      1
# 288     1
# 143     1
# 142     1
# 200     1
# 58      1
# 55      1
# 60      1
# 175     1
# 154     1
# 72      1
# 120     1
# 64      1
# 135     1
# 262     1
# 106     1
# Name: horsepower, dtype: int64

# %%
sb.heatmap(gg.isnull())
plt.show()

# %%
gg.isnull().sum()/gg.shape[0]*100
# Out:
# symboling            0.00000
# normalized-losses    0.00000
# make                 0.00000
# fuel-type            0.00000
# body-style           0.00000
# drive-wheels         0.00000
# engine-location      0.00000
# width                0.00000
# height               0.00000
# engine-type          0.00000
# engine-size          0.00000
# horsepower           0.97561
# city-mpg             0.00000
# highway-mpg          0.00000
# price                0.00000
# dtype: float64

# %%
gg['horsepower']=gg['horsepower'].astype('float')

# %%
gg.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower           float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
h=gg['horsepower'].mean()
# Out:
# 104.25615763546799

# %%
gg['horsepower'].fillna(m,inplace=True)

# %%
sb.heatmap(gg.isnull())
# Out:
# <Axes: >

# %%
gg.to_csv('rr1.csv',index='False',encoding='utf-8')

# %%
class1={
    'CLASS':['A','B','C','D','E','F','G','H','I','J'],
    'PERCENT':['?',78,56,44,'?','?',43,'?',67,'?'],
    'MARKS':[56,78,'?',45,'?',65,90,'?','?','?'],
    
    
}

g1=pd.DataFrame(class1)
g1
# Out:
#   CLASS PERCENT MARKS
# 0     A       ?    56
# 1     B      78    78
# 2     C      56     ?
# 3     D      44    45
# 4     E       ?     ?
# 5     F       ?    65
# 6     G      43    90
# 7     H       ?     ?
# 8     I      67     ?
# 9     J       ?     ?

# %%
g1['PERCENT'].unique()
# Out:
# array(['?', 78, 56, 44, 43, 67], dtype=object)

# %%
g1['PERCENT'].value_counts()
# Out:
# ?     5
# 78    1
# 56    1
# 44    1
# 43    1
# 67    1
# Name: PERCENT, dtype: int64

# %%
sb.heatmap(g1.isnull())
plt.show()

# %%
g1['PERCENT'].replace('?',np.nan,inplace=True)

# %%
sb.heatmap(g1.isnull())
# Out:
# <Axes: >

# %%
g1.dtypes
# Out:
# CLASS       object
# PERCENT    float64
# MARKS       object
# dtype: object

# %%
g1['PERCENT']=g1['PERCENT'].astype('float')

# %%
g1
# Out:
#   CLASS  PERCENT MARKS
# 0     A      NaN    56
# 1     B     78.0    78
# 2     C     56.0     ?
# 3     D     44.0    45
# 4     E      NaN     ?
# 5     F      NaN    65
# 6     G     43.0    90
# 7     H      NaN     ?
# 8     I     67.0     ?
# 9     J      NaN     ?

# %%
g1.isnull().sum()/g1.shape[0]*100
# Out:
# CLASS       0.0
# PERCENT    50.0
# MARKS       0.0
# dtype: float64

# %%
mm=g1['PERCENT'].mean()
print(mm)
# Out:
# 57.6

# %%
g1['PERCENT'].replace(122,np.nan,inplace=True)

# %%
g1['PERCENT'].fillna(mm,inplace=True)

# %%
g1.head()
# Out:
#   CLASS  PERCENT MARKS
# 0     A     57.6    56
# 1     B     78.0    78
# 2     C     56.0     ?
# 3     D     44.0    45
# 4     E     57.6     ?

# %%
sb.heatmap(g1.isnull())
# Out:
# <Axes: >

# %%
g1.dtypes
# Out:
# CLASS       object
# PERCENT    float64
# MARKS       object
# dtype: object

# %%
g1['MARKS'].value_counts()
# Out:
# ?     5
# 56    1
# 78    1
# 45    1
# 65    1
# 90    1
# Name: MARKS, dtype: int64

# %%
g1['MARKS'].unique()
# Out:
# array([56, 78, '?', 45, 65, 90], dtype=object)

# %%
g1['MARKS'].replace('?',np.nan,inplace=True)

# %%
g1.head()
# Out:
#   CLASS  PERCENT  MARKS
# 0     A     57.6   56.0
# 1     B     78.0   78.0
# 2     C     56.0    NaN
# 3     D     44.0   45.0
# 4     E     57.6    NaN

# %%
g1['MARKS']=g1['MARKS'].astype('float')

# %%
g1.dtypes
# Out:
# CLASS       object
# PERCENT    float64
# MARKS      float64
# dtype: object

# %%
g1.isnull().sum()/g1.shape[0]*100
# Out:
# CLASS       0.0
# PERCENT     0.0
# MARKS      50.0
# dtype: float64

# %%
b=g1['MARKS'].mean()
print(b)
# Out:
# 66.8

# %%
sb.heatmap(g1.isnull())
# Out:
# <Axes: >

# %%
g1['MARKS'].fillna(b,inplace=True)

# %%
g1.head()
# Out:
#   CLASS  PERCENT  MARKS
# 0     A     57.6   56.0
# 1     B     78.0   78.0
# 2     C     56.0   66.8
# 3     D     44.0   45.0
# 4     E     57.6   66.8

# %%
sb.heatmap(g1.isnull())
# Out:
# <Axes: >

# %%
car={
    'car_name':['ferrari','porsche','Buggati','lambo','mercedes','bmw','aston_martin'],
    'car_price':[4.5,2.22,'?','?',5.6,1.5,'>'],
    'car_cc':[565,'?',550,660,'?','>',340],
}
car
# Out:
# {'car_name': ['ferrari',
#   'porsche',
#   'Buggati',
#   'lambo',
#   'mercedes',
#   'bmw',
#   'aston_martin'],
#  'car_price': [4.5, 2.22, '?', '?', 5.6, 1.5, '>'],
#  'car_cc': [565, '?', 550, 660, '?', '>', 340]}

# %%
cd=pd.DataFrame(car)
cd
# Out:
#        car_name car_price car_cc
# 0       ferrari       4.5    565
# 1       porsche      2.22      ?
# 2       Buggati         ?    550
# 3         lambo         ?    660
# 4      mercedes       5.6      ?
# 5           bmw       1.5      >
# 6  aston_martin         >    340

# %%
cd.dtypes
# Out:
# car_name     object
# car_price    object
# car_cc       object
# dtype: object

# %%
cd['car_price'].unique()
# Out:
# array([4.5, 2.22, '?', 5.6, 1.5, '>'], dtype=object)

# %%
cd['car_price'].value_counts()
# Out:
# ?       2
# 4.5     1
# 2.22    1
# 5.6     1
# 1.5     1
# >       1
# Name: car_price, dtype: int64

# %%
cd['car_price'].replace('?',np.nan,inplace=True)
cd['car_price'].replace('>',np.nan,inplace=True)

# %%
sb.heatmap(cd.isnull())
plt.show()

# %%
cd.isnull().sum()/cd.shape[0]*100
# Out:
# car_name      0.000000
# car_price    42.857143
# car_cc        0.000000
# dtype: float64

# %%
q=cd['car_price'].mean()
print(q)
# Out:
# 3.455

# %%
cd['car_price'].fillna(q,inplace=True)

# %%
sb.heatmap(cd.isnull())
plt.show()

# %%
cd.dtypes
# Out:
# car_name      object
# car_price    float64
# car_cc        object
# dtype: object

# %%
cd
# Out:
#        car_name  car_price car_cc
# 0       ferrari      4.500    565
# 1       porsche      2.220      ?
# 2       Buggati      3.455    550
# 3         lambo      3.455    660
# 4      mercedes      5.600      ?
# 5           bmw      1.500      >
# 6  aston_martin      3.455    340

# %%
cd['car_cc'].unique()
# Out:
# array([565, '?', 550, 660, '>', 340], dtype=object)

# %%
cd['car_cc'].value_counts()
# Out:
# ?      2
# 565    1
# 550    1
# 660    1
# >      1
# 340    1
# Name: car_cc, dtype: int64

# %%
cd['car_cc'].replace('?',np.nan,inplace=True)
cd['car_cc'].replace('>',np.nan,inplace=True)

# %%
cd['car_cc'].unique()
# Out:
# array([565.,  nan, 550., 660., 340.])

# %%
cd['car_cc'].value_counts()
# Out:
# 565.0    1
# 550.0    1
# 660.0    1
# 340.0    1
# Name: car_cc, dtype: int64

# %%
cd['car_cc']=cd['car_cc'].astype('float')

# %%
cd.dtypes
# Out:
# car_name      object
# car_price    float64
# car_cc       float64
# dtype: object

# %%
sb.heatmap(cd.isnull())
# Out:
# <Axes: >

# %%
cd.isnull().sum()/cd.shape[0]*100
# Out:
# car_name      0.000000
# car_price     0.000000
# car_cc       42.857143
# dtype: float64

# %%
w=cd['car_cc'].mean()

# %%
cd['car_cc'].fillna(w,inplace=True)

# %%
cd
# Out:
#        car_name  car_price  car_cc
# 0       ferrari      4.500  565.00
# 1       porsche      2.220  528.75
# 2       Buggati      3.455  550.00
# 3         lambo      3.455  660.00
# 4      mercedes      5.600  528.75
# 5           bmw      1.500  528.75
# 6  aston_martin      3.455  340.00

# %%
sb.heatmap(cd.isnull())
# Out:
# <Axes: >

# %%
j=pd.read_csv('fifa21_raw_data.csv')
j
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 j=pd.read_csv('fifa21_raw_data.csv')
#       2 j
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
