# %%
import requests

url = "https://imdb8.p.rapidapi.com/auto-complete"

querystring = {"q":"game of thr"}

headers = {
	"X-RapidAPI-Key": "09c530d9b1msh2896fd00235ede6p1d03b7jsnf5c497c06a8f",
	"X-RapidAPI-Host": "imdb8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'d': [{'i': {'height': 1500, 'imageUrl': 'https://m.media-amazon.com/images/M/MV5BN2IzYzBiOTQtNGZmMi00NDI5LTgxMzMtN2EzZjA1NjhlOGMxXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_.jpg', 'width': 1000}, 'id': 'tt0944947', 'l': 'Game of Thrones', 'q': 'TV series', 'qid': 'tvSeries', 'rank': 30, 's': 'Emilia Clarke, Peter Dinklage', 'y': 2011, 'yr': '2011-2019'}, {'i': {'height': 1200, 'imageUrl': 'https://m.media-amazon.com/images/M/MV5BNTg1MjEyNWYtNzJkZi00ZTM5LThlNWMtMmNiNmE3N2QxNTllXkEyXkFqcGdeQXVyNTE1NjY5Mg@@._V1_.jpg', 'width': 782}, 'id': 'tt13380510', 'l': 'Game of Thrones', 'q': 'video', 'qid': 'video', 'rank': 6781, 's': 'Roy Dotrice', 'y': 2003}, {'id': 'tt21073266', 'l': 'Untitled Jon Snow/Game of Thrones Spinoff', 'q': 'TV series', 'qid': 'tvSeries', 'rank': 12912, 's': ''}, {'i': {'height': 1200, 'imageUrl': 'https://m.media-amazon.com/images/M/MV5BZDdlMzQzNDQtNTAxMS00NTMyLTgxYTAtYzQ0OGI1YzZhY2Y3XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_.jpg', 'width': 810}, 'id': 'tt10090796', 'l': 'Game of Thron
# ...

# %%
a=response.json()

# %%
type(a)
# Out:
# dict

# %%
a.keys()
# Out:
# dict_keys(['d', 'q', 'v'])

# %%
data1=[]

# %%
for i in a['d']:
    data1.append(i)

# %%
import pandas as pd

# %%
data1
# Out:
# [{'i': {'height': 1500,
#    'imageUrl': 'https://m.media-amazon.com/images/M/MV5BN2IzYzBiOTQtNGZmMi00NDI5LTgxMzMtN2EzZjA1NjhlOGMxXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_.jpg',
#    'width': 1000},
#   'id': 'tt0944947',
#   'l': 'Game of Thrones',
#   'q': 'TV series',
#   'qid': 'tvSeries',
#   'rank': 30,
#   's': 'Emilia Clarke, Peter Dinklage',
#   'y': 2011,
#   'yr': '2011-2019'},
#  {'i': {'height': 1200,
#    'imageUrl': 'https://m.media-amazon.com/images/M/MV5BNTg1MjEyNWYtNzJkZi00ZTM5LThlNWMtMmNiNmE3N2QxNTllXkEyXkFqcGdeQXVyNTE1NjY5Mg@@._V1_.jpg',
#    'width': 782},
#   'id': 'tt13380510',
#   'l': 'Game of Thrones',
#   'q': 'video',
#   'qid': 'video',
#   'rank': 6781,
#   's': 'Roy Dotrice',
#   'y': 2003},
#  {'id': 'tt21073266',
#   'l': 'Untitled Jon Snow/Game of Thrones Spinoff',
#   'q': 'TV series',
#   'qid': 'tvSeries',
#   'rank': 12912,
#   's': ''},
#  {'i': {'height': 1200,
# ...

# %%
df1=pd.DataFrame(data1)
df1
# Out:
#                                                    i          id  \
# 0  {'height': 1500, 'imageUrl': 'https://m.media-...   tt0944947
# 1  {'height': 1200, 'imageUrl': 'https://m.media-...  tt13380510
# 2                                                NaN  tt21073266
# 3  {'height': 1200, 'imageUrl': 'https://m.media-...  tt10090796
# 4  {'height': 750, 'imageUrl': 'https://m.media-a...   tt6857128
# 5  {'height': 1920, 'imageUrl': 'https://m.media-...  tt11198330
# 6  {'height': 375, 'imageUrl': 'https://m.media-a...   tt2653342
# 7  {'height': 1330, 'imageUrl': 'https://m.media-...   tt6411748
#
#                                                 l          q       qid   rank  \
# 0                                 Game of Thrones  TV series  tvSeries     30
# 1                                 Game of Thrones      video     video   6781
# 2       Untitled Jon Snow/Game of Thrones Spinoff  TV series  tvSeries  12912
# ...

# %%
data2=[]

# %%
print(type(a['q']))
# Out:
# <class 'str'>

# %%
for i in a['q']:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
data2
# Out:
# []

# %%
a['v']
# Out:
# 1

# %%
df1=pd.DataFrame(data1)
df1
# Out:
#                                                    i          id  \
# 0  {'height': 1500, 'imageUrl': 'https://m.media-...   tt0944947
# 1  {'height': 1200, 'imageUrl': 'https://m.media-...  tt13380510
# 2                                                NaN  tt21073266
# 3  {'height': 1200, 'imageUrl': 'https://m.media-...  tt10090796
# 4  {'height': 750, 'imageUrl': 'https://m.media-a...   tt6857128
# 5  {'height': 1920, 'imageUrl': 'https://m.media-...  tt11198330
# 6  {'height': 375, 'imageUrl': 'https://m.media-a...   tt2653342
# 7  {'height': 1330, 'imageUrl': 'https://m.media-...   tt6411748
#
#                                                 l          q       qid   rank  \
# 0                                 Game of Thrones  TV series  tvSeries     30
# 1                                 Game of Thrones      video     video   6781
# 2       Untitled Jon Snow/Game of Thrones Spinoff  TV series  tvSeries  12912
# ...

# %%
# df1.fillna(1,inplace=True)

# %%
df1.dtypes
# Out:
# i        object
# id       object
# l        object
# q        object
# qid      object
# rank      int64
# s        object
# y       float64
# yr       object
# dtype: object

# %%
df1['i']
# Out:
# 0    {'height': 1500, 'imageUrl': 'https://m.media-...
# 1    {'height': 1200, 'imageUrl': 'https://m.media-...
# 2                                                  NaN
# 3    {'height': 1200, 'imageUrl': 'https://m.media-...
# 4    {'height': 750, 'imageUrl': 'https://m.media-a...
# 5    {'height': 1920, 'imageUrl': 'https://m.media-...
# 6    {'height': 375, 'imageUrl': 'https://m.media-a...
# 7    {'height': 1330, 'imageUrl': 'https://m.media-...
# Name: i, dtype: object

# %%
df2=pd.DataFrame(df1,columns=['i','height','imageUrl','width','id','l','q','qid','rank','s','y','yr'])

# %%
df2
# Out:
#                                                    i  height  imageUrl  width  \
# 0  {'height': 1500, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 1  {'height': 1200, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 2                                                NaN     NaN       NaN    NaN
# 3  {'height': 1200, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 4  {'height': 750, 'imageUrl': 'https://m.media-a...     NaN       NaN    NaN
# 5  {'height': 1920, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 6  {'height': 375, 'imageUrl': 'https://m.media-a...     NaN       NaN    NaN
# 7  {'height': 1330, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
#
#            id                                               l          q  \
# 0   tt0944947                                 Game of Thrones  TV series
# 1  tt13380510                                 Game of Thrones      video
# ...

# %%
add=df2.iloc[2]
add
# Out:
# i                                                 NaN
# height                                            NaN
# imageUrl                                          NaN
# width                                             NaN
# id                                         tt21073266
# l           Untitled Jon Snow/Game of Thrones Spinoff
# q                                           TV series
# qid                                          tvSeries
# rank                                            12912
# s
# y                                                 NaN
# yr                                                NaN
# Name: 2, dtype: object

# %%
# l=df2.iloc[2].index

# %%
df2.drop(2,inplace=True)

# %%
# import re
# df2['i'] = df2['i'].apply(lambda x: re.findall(r"\d", str(x)))

# %%
df2
# Out:
#                                                    i  height  imageUrl  width  \
# 0  {'height': 1500, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 1  {'height': 1200, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 3  {'height': 1200, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 4  {'height': 750, 'imageUrl': 'https://m.media-a...     NaN       NaN    NaN
# 5  {'height': 1920, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 6  {'height': 375, 'imageUrl': 'https://m.media-a...     NaN       NaN    NaN
# 7  {'height': 1330, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
#
#            id                                               l          q  \
# 0   tt0944947                                 Game of Thrones  TV series
# 1  tt13380510                                 Game of Thrones      video
# 3  tt10090796                 Game of Thrones: The Last Watch   TV movie
# ...

# %%
df2['i']
# Out:
# 0    {'height': 1500, 'imageUrl': 'https://m.media-...
# 1    {'height': 1200, 'imageUrl': 'https://m.media-...
# 3    {'height': 1200, 'imageUrl': 'https://m.media-...
# 4    {'height': 750, 'imageUrl': 'https://m.media-a...
# 5    {'height': 1920, 'imageUrl': 'https://m.media-...
# 6    {'height': 375, 'imageUrl': 'https://m.media-a...
# 7    {'height': 1330, 'imageUrl': 'https://m.media-...
# Name: i, dtype: object

# %%
for i in df2['i']:
    print(i)
# Out:
# {'height': 1500, 'imageUrl': 'https://m.media-amazon.com/images/M/MV5BN2IzYzBiOTQtNGZmMi00NDI5LTgxMzMtN2EzZjA1NjhlOGMxXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_.jpg', 'width': 1000}
# {'height': 1200, 'imageUrl': 'https://m.media-amazon.com/images/M/MV5BNTg1MjEyNWYtNzJkZi00ZTM5LThlNWMtMmNiNmE3N2QxNTllXkEyXkFqcGdeQXVyNTE1NjY5Mg@@._V1_.jpg', 'width': 782}
# {'height': 1200, 'imageUrl': 'https://m.media-amazon.com/images/M/MV5BZDdlMzQzNDQtNTAxMS00NTMyLTgxYTAtYzQ0OGI1YzZhY2Y3XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_.jpg', 'width': 810}
# {'height': 750, 'imageUrl': 'https://m.media-amazon.com/images/M/MV5BODg5NDJhMjYtMTYyYi00NzAwLTliNmYtNGZhMjQ4ZjNkMjgyXkEyXkFqcGdeQXVyNTA3MTU2MjE@._V1_.jpg', 'width': 1334}
# {'height': 1920, 'imageUrl': 'https://m.media-amazon.com/images/M/MV5BMjk2NjgzMTEtYWViZS00NTMyLWFjMzctODczYmQzNzk2NjIwXkEyXkFqcGdeQXVyMTEyMjM2NDc2._V1_.jpg', 'width': 1296}
# ...

# %%
height=[]

# %%
for i in df2['i']:
    print(i['height'])
    height.append(i['height'])
# Out:
# 1500
# 1200
# 1200
# 750
# 1920
# 375
# 1330

# %%
height
# Out:
# [1500, 1200, 1200, 750, 1920, 375, 1330]

# %%
image_url=[]

# %%
for i in df2['i']:
    print(i['imageUrl'])
    image_url.append(i['imageUrl'])
# Out:
# https://m.media-amazon.com/images/M/MV5BN2IzYzBiOTQtNGZmMi00NDI5LTgxMzMtN2EzZjA1NjhlOGMxXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_.jpg
# https://m.media-amazon.com/images/M/MV5BNTg1MjEyNWYtNzJkZi00ZTM5LThlNWMtMmNiNmE3N2QxNTllXkEyXkFqcGdeQXVyNTE1NjY5Mg@@._V1_.jpg
# https://m.media-amazon.com/images/M/MV5BZDdlMzQzNDQtNTAxMS00NTMyLTgxYTAtYzQ0OGI1YzZhY2Y3XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_.jpg
# https://m.media-amazon.com/images/M/MV5BODg5NDJhMjYtMTYyYi00NzAwLTliNmYtNGZhMjQ4ZjNkMjgyXkEyXkFqcGdeQXVyNTA3MTU2MjE@._V1_.jpg
# https://m.media-amazon.com/images/M/MV5BMjk2NjgzMTEtYWViZS00NTMyLWFjMzctODczYmQzNzk2NjIwXkEyXkFqcGdeQXVyMTEyMjM2NDc2._V1_.jpg
# https://m.media-amazon.com/images/M/MV5BMTU1MzU2MDE4MV5BMl5BanBnXkFtZTgwNTc3NzA2MDE@._V1_.jpg
# https://m.media-amazon.com/images/M/MV5BMzc3M2U2NzAtMmY1MS00NWYwLWFmMzctYzE2NWEyODYxNTk4XkEyXkFqcGdeQXVyMzIzNzE4Njk@._V1_.jpg

# %%
image_url
# Out:
# ['https://m.media-amazon.com/images/M/MV5BN2IzYzBiOTQtNGZmMi00NDI5LTgxMzMtN2EzZjA1NjhlOGMxXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNTg1MjEyNWYtNzJkZi00ZTM5LThlNWMtMmNiNmE3N2QxNTllXkEyXkFqcGdeQXVyNTE1NjY5Mg@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZDdlMzQzNDQtNTAxMS00NTMyLTgxYTAtYzQ0OGI1YzZhY2Y3XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BODg5NDJhMjYtMTYyYi00NzAwLTliNmYtNGZhMjQ4ZjNkMjgyXkEyXkFqcGdeQXVyNTA3MTU2MjE@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMjk2NjgzMTEtYWViZS00NTMyLWFjMzctODczYmQzNzk2NjIwXkEyXkFqcGdeQXVyMTEyMjM2NDc2._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMTU1MzU2MDE4MV5BMl5BanBnXkFtZTgwNTc3NzA2MDE@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMzc3M2U2NzAtMmY1MS00NWYwLWFmMzctYzE2NWEyODYxNTk4XkEyXkFqcGdeQXVyMzIzNzE4Njk@._V1_.jpg']

# %%
df2['height']
# Out:
# 0   NaN
# 1   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# Name: height, dtype: float64

# %%
df2['height1']=height

# %%
df2
# Out:
#                                                    i  height  imageUrl  width  \
# 0  {'height': 1500, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 1  {'height': 1200, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 3  {'height': 1200, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 4  {'height': 750, 'imageUrl': 'https://m.media-a...     NaN       NaN    NaN
# 5  {'height': 1920, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 6  {'height': 375, 'imageUrl': 'https://m.media-a...     NaN       NaN    NaN
# 7  {'height': 1330, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
#
#            id                                               l          q  \
# 0   tt0944947                                 Game of Thrones  TV series
# 1  tt13380510                                 Game of Thrones      video
# 3  tt10090796                 Game of Thrones: The Last Watch   TV movie
# ...

# %%
df2['image_Url']=image_url

# %%
df2
# Out:
#                                                    i  height  imageUrl  width  \
# 0  {'height': 1500, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 1  {'height': 1200, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 3  {'height': 1200, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 4  {'height': 750, 'imageUrl': 'https://m.media-a...     NaN       NaN    NaN
# 5  {'height': 1920, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
# 6  {'height': 375, 'imageUrl': 'https://m.media-a...     NaN       NaN    NaN
# 7  {'height': 1330, 'imageUrl': 'https://m.media-...     NaN       NaN    NaN
#
#            id                                               l          q  \
# 0   tt0944947                                 Game of Thrones  TV series
# 1  tt13380510                                 Game of Thrones      video
# 3  tt10090796                 Game of Thrones: The Last Watch   TV movie
# ...

# %%
df2.drop(['imageUrl'],axis=1,inplace=True)

# %%
df2.drop(['height'],axis=1,inplace=True)

# %%
df2.drop(['width'],axis=1,inplace=True)

# %%
df2
# Out:
#                                                    i          id  \
# 0  {'height': 1500, 'imageUrl': 'https://m.media-...   tt0944947
# 1  {'height': 1200, 'imageUrl': 'https://m.media-...  tt13380510
# 3  {'height': 1200, 'imageUrl': 'https://m.media-...  tt10090796
# 4  {'height': 750, 'imageUrl': 'https://m.media-a...   tt6857128
# 5  {'height': 1920, 'imageUrl': 'https://m.media-...  tt11198330
# 6  {'height': 375, 'imageUrl': 'https://m.media-a...   tt2653342
# 7  {'height': 1330, 'imageUrl': 'https://m.media-...   tt6411748
#
#                                                 l          q       qid   rank  \
# 0                                 Game of Thrones  TV series  tvSeries     30
# 1                                 Game of Thrones      video     video   6781
# 3                 Game of Thrones: The Last Watch   TV movie   tvMovie  26488
# 4           Unaired Game of Thrones Prequel Pilot   TV movie   tvMovie  21245
# ...

# %%
width=[]

# %%
for q in df2['i']:
    print(q['width'])
    width.append(q['width'])
# Out:
# 1000
# 782
# 810
# 1334
# 1296
# 500
# 1021

# %%
width
# Out:
# [1000, 782, 810, 1334, 1296, 500, 1021]

# %%
df2['width']=width

# %%
width=[]

# %%
df2
# Out:
#                                                    i          id  \
# 0  {'height': 1500, 'imageUrl': 'https://m.media-...   tt0944947
# 1  {'height': 1200, 'imageUrl': 'https://m.media-...  tt13380510
# 3  {'height': 1200, 'imageUrl': 'https://m.media-...  tt10090796
# 4  {'height': 750, 'imageUrl': 'https://m.media-a...   tt6857128
# 5  {'height': 1920, 'imageUrl': 'https://m.media-...  tt11198330
# 6  {'height': 375, 'imageUrl': 'https://m.media-a...   tt2653342
# 7  {'height': 1330, 'imageUrl': 'https://m.media-...   tt6411748
#
#                                                 l          q       qid   rank  \
# 0                                 Game of Thrones  TV series  tvSeries     30
# 1                                 Game of Thrones      video     video   6781
# 3                 Game of Thrones: The Last Watch   TV movie   tvMovie  26488
# 4           Unaired Game of Thrones Prequel Pilot   TV movie   tvMovie  21245
# ...

# %%
# df2.loc[len(df2)] = add

# %%
# df2

# %%
df2 = df2.append(add,ignore_index=True)         #ignore_index=True
# Out:
# C:\Users\yash\AppData\Local\Temp\ipykernel_16624\3460764210.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(add,ignore_index=True)         #ignore_index=True

# %%
df2
# Out:
#                                                    i          id  \
# 0  {'height': 1500, 'imageUrl': 'https://m.media-...   tt0944947
# 1  {'height': 1200, 'imageUrl': 'https://m.media-...  tt13380510
# 2  {'height': 1200, 'imageUrl': 'https://m.media-...  tt10090796
# 3  {'height': 750, 'imageUrl': 'https://m.media-a...   tt6857128
# 4  {'height': 1920, 'imageUrl': 'https://m.media-...  tt11198330
# 5  {'height': 375, 'imageUrl': 'https://m.media-a...   tt2653342
# 6  {'height': 1330, 'imageUrl': 'https://m.media-...   tt6411748
# 7                                                NaN  tt21073266
#
#                                                 l          q       qid   rank  \
# 0                                 Game of Thrones  TV series  tvSeries     30
# 1                                 Game of Thrones      video     video   6781
# 2                 Game of Thrones: The Last Watch   TV movie   tvMovie  26488
# ...

# %%
df2.drop(['i'],inplace=True,axis=1)

# %%
df2
# Out:
#            id                                               l          q  \
# 0   tt0944947                                 Game of Thrones  TV series
# 1  tt13380510                                 Game of Thrones      video
# 2  tt10090796                 Game of Thrones: The Last Watch   TV movie
# 3   tt6857128           Unaired Game of Thrones Prequel Pilot   TV movie
# 4  tt11198330                             House of the Dragon  TV series
# 5   tt2653342  Game of Thrones: Season 2 - Character Profiles      video
# 6   tt6411748                               Purge of Kingdoms    feature
# 7  tt21073266       Untitled Jon Snow/Game of Thrones Spinoff  TV series
#
#         qid   rank                                  s       y         yr  \
# 0  tvSeries     30      Emilia Clarke, Peter Dinklage  2011.0  2011-2019
# 1     video   6781                        Roy Dotrice  2003.0        NaN
# 2   tvMovie  26488       Kevin Alexander, Alfie Allen  2019.0        NaN
# ...

# %%
df2.drop(['imageUrl'],axis=1,inplace=True)

# %%
df2.drop(['height'],axis=1,inplace=True)

# %%
df2
# Out:
#            id                                               l          q  \
# 0   tt0944947                                 Game of Thrones  TV series
# 1  tt13380510                                 Game of Thrones      video
# 2  tt10090796                 Game of Thrones: The Last Watch   TV movie
# 3   tt6857128           Unaired Game of Thrones Prequel Pilot   TV movie
# 4  tt11198330                             House of the Dragon  TV series
# 5   tt2653342  Game of Thrones: Season 2 - Character Profiles      video
# 6   tt6411748                               Purge of Kingdoms    feature
# 7  tt21073266       Untitled Jon Snow/Game of Thrones Spinoff  TV series
#
#         qid   rank                                  s       y         yr  \
# 0  tvSeries     30      Emilia Clarke, Peter Dinklage  2011.0  2011-2019
# 1     video   6781                        Roy Dotrice  2003.0        NaN
# 2   tvMovie  26488       Kevin Alexander, Alfie Allen  2019.0        NaN
# ...

# %%
df2.fillna('no information',inplace=True)

# %%
df2
# Out:
#            id                                               l          q  \
# 0   tt0944947                                 Game of Thrones  TV series
# 1  tt13380510                                 Game of Thrones      video
# 2  tt10090796                 Game of Thrones: The Last Watch   TV movie
# 3   tt6857128           Unaired Game of Thrones Prequel Pilot   TV movie
# 4  tt11198330                             House of the Dragon  TV series
# 5   tt2653342  Game of Thrones: Season 2 - Character Profiles      video
# 6   tt6411748                               Purge of Kingdoms    feature
# 7  tt21073266       Untitled Jon Snow/Game of Thrones Spinoff  TV series
#
#         qid   rank                                  s               y  \
# 0  tvSeries     30      Emilia Clarke, Peter Dinklage          2011.0
# 1     video   6781                        Roy Dotrice          2003.0
# 2   tvMovie  26488       Kevin Alexander, Alfie Allen          2019.0
# ...
